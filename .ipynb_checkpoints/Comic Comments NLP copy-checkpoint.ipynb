# %% [markdown]
# # Webscraping and analyzing reviews on comics for readcomiconline.to

# %%
# GENERAL
import re
import json
import numpy as np
import pandas as pd

# WEBSCRAPING
import requests
import bs4 as bs

# SELENIUM
from selenium import webdriver
from selenium.webdriver.support.wait import WebDriverWait

# NLP
import spacy
from textblob import TextBlob
from collections import Counter
from nltk import word_tokenize
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# GRAPHICS
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # 0. Webscrape results, export to dataframe

# %% [markdown]
# ## 0.0 Functions

# %%
def harvest(urls, df=None, outfile="comic_comments/comic_comments.csv"):
    """
    Takes a list of urls of comic series and a df (optional)
    Scrapes and runs NLP for every comic series url in the list.
    Scrapes comments, populates tables and exports CSVs for every issue in the series.
    Returns df of all comics/comments
    """
    # INITIATE DF IF NOT PASSED IN
    if df is None:
        df = pd.DataFrame(columns=['Webpage','Message', 'Author', 'Likes', 'Dislikes', 'NumReports'])
        print("new df created")

    else:
        print(f"df loaded. df length: {len(df)}")

    # CALLS SCRAPE_SERIES FOR EACH SERIES, UPDATES df
    for series_homepage in urls:
        df = scrape_series(series_homepage=series_homepage, outfile=outfile, df=df)
        
    return df

# %%
# SCRAPE COMIC SERIES URL - GET ALL ISSUES URL
def get_issues(series_homepage):
    """
    Takes in a url for a comic series
    Returns a list of every comic's link in the series
    """
    
    # INSTANTATE SELENIUM WEBDRIVER
#     driver = webdriver.Opera(executable_path='webdriver/operadriver_mac64/operadriver')
    driver = webdriver.Chrome(executable_path='webdriver/chromedriver')

    # LOAD COMIC SERIES PAGE TO SCRAPE
    driver.get(series_homepage)
    driver.implicitly_wait(15) # Wait to load
    
    # GET LIST OF issue_urls
    issue_table = driver.find_element_by_class_name("listing")
    all_issues = issue_table.find_elements_by_tag_name("a")
    issue_urls = [issue.get_attribute("href") for issue in all_issues]
    print(f"Get Issues: total issues found: {len(issue_urls)}")
    driver.close() # close webpage
    return(issue_urls)

# %%
def scrape_series(series_homepage, outfile="comic_comments/comic_comments.csv", df=None, prev_fails=0):
    """
    Takes in a comic series homepage (e.g. https://readcomiconline.to/Comic/The-Wild-Storm/)
    Can be passed a df with some issues already scraped (df=None)
    Can set the outfile (outfile="comic_comments/comic_comments.csv")
    Saves running df of scraped comments to outfile
    Returns a df populated with comments for all scraped issues for the series
    """
    print(f"Scrape_series initaiated for {series_homepage}")
    fails = 0
    max_fails = 12
    issues_scraped = 0
    
    # INITIATE DF IF NOT PASSED IN
    if df is None:
        df = pd.DataFrame(columns=['Webpage','Message', 'Author', 'Likes', 'Dislikes', 'NumReports'])
        print("new df created")

    else:
        print(f"df loaded. df length: {len(df)}")

    # GET ALL ISSUE URLS FOR A SERIES
    issue_urls = get_issues(series_homepage)
    print(f"Scrape_series: {len(issue_urls)} issues found for {series_homepage}")
    
    # FOR EVERY ISSUE IN THE SERIES...
    for issue_url in issue_urls:
        if fails >= max_fails: # MAX FAILS CONDITION (CAPTCHA NEEDS TO BE TOLD YOU'RE A HUMAN)
            print("Max fails reached. Breaking")
            break
        else:
            # REMOVE UNNECESSARY PARAMETERS FROM issue_name (IF PRESENT)
            if "?" in issue_url:
                issue_url = issue_url[:issue_url.find('?id')]

            issue_name = issue_url[33:]

            # ... IF THE ISSUE HAS NOT BEEN SCRAPED YET...
            if issue_name not in df['Webpage'].values:
                print(f"Now scraping: {issue_url}")

                # ... RUN ALL WEBSCRAPING FUNCTIONS
                try:       
                    soup = get_comment_soup(issue_url)
                    json_data = soup_to_json(soup)
                    df = get_messages(df, issue_name, json_data)
                    df.to_csv(outfile) # SAVE AFTER EVERY SUCCESSFUL ISSUE SCRAPE
                    issues_scraped = issues_scraped + 1
                    print(f"Total issues scraped: {issues_scraped}")
                # IF WEBSCRAPING FAILS
                except:
                    fails = fails + 1
                    print(f"SCRAPING FAILED for {issue_url} - total fails: {fails}")
                    
                    continue
            else:
                print(f"{issue_name} already scraped.")
                
    # IF ANY ISSUE FAILED TO SCRAPE...
    print(f"Scraped {series_homepage} with {fails} fails.")
    if fails > 0 and fails < max_fails:
        if fails != prev_fails: # ...IF FAILS NOT SAME AS BEFORE, RUNS FUNCTION RECURSIVELY
            df = scrape_series(series_homepage=series_homepage, df=df, prev_fails=fails)
        else:
            print(f"TOTAL SCRAPE FAILS: {fails}")
    
    return df

# %%
def get_comment_soup(issue_url):
    """
    For a given url, driver, uses Selenium to get the "src" link to the Disqus comments page.
    Returns bs4 soup file for Disqus comments page.
    """
    
    # INSTANTATE SELENIUM WEBDRIVER
#     driver = webdriver.Opera(executable_path='webdriver/operadriver_mac64/operadriver')
    driver = webdriver.Chrome(executable_path='webdriver/chromedriver')
    
#     driver.implicitly_wait(60) # Wait 1 minute to reduce CAPTCHA issues
    
    driver.get(issue_url)
    driver.implicitly_wait(15) # Wait to load
    
#     frame = driver.find_elements_by_id("disqus_thread")
#     print("Disqus Threads elements:",len(frame))
    
    iframe = driver.find_elements_by_css_selector("[title='Disqus']")

    iframe_url = iframe[1].get_attribute('src') # "src" is link to Disqus comments (second iframe in the list)
    
#     print(iframe_url)
    driver.close() # close webpage

    # Instantiate BS, create soup for Disqus url
    source_code = requests.get(iframe_url)
    plain_text = source_code.text
    soup = bs.BeautifulSoup(plain_text, 'html.parser')
#     print(soup)
    return soup

# %%
def soup_to_json(soup):
    """
    Returns json-formatted messages of bs4 soup file
    Returns json_data, a list of dicts
    """
    json_data_str = str(soup.find("script", {"id" : "disqus-threadData"})) # string of json_data
    json_data_str2 = json_data_str[json_data_str.find('json')+6:-9] # remove head/foot tags
    json_data = json.loads(json_data_str2) # string to json
    json_data = json_data['response']['posts']
    
    return json_data

# %%
def get_messages(df, issue_name, json_data):
    """
    Takes in a df of form ['Webpage','Message', 'Author', 'Likes', 'Dislikes', 'NumReports']
    Appends each message and metadata (50 max) to that df.
    Returns the updated df
    """        
    # Check all messages (50 max) per issue
    
    # IF THERE ARE NO COMMENTS
    if len(json_data) == 0:
        message = "NO_COMMENTS"
        author, likes, dislikes, numReports = "", "", "", ""
        data=[issue_name, message, author, likes, dislikes, numReports]
        append_me = pd.Series(data=data, index = df.columns)
        df = df.append(append_me, ignore_index=True) # Append the "NO_COMMENTS" Series into df

    # IF THERE ARE ANY COMMENTS
    else:
        # LOG EVERY COMMENT
        for i in range(len(json_data)):

            message = json_data[i]['message'] # MESSAGE
            message = re.compile(r'<[^>]+>').sub('', message) # remove all html tags
            try:
                author = json_data[i]['author']['username'] # if the author has a username
            except:
                author = json_data[i]['author']['name'] # if the author is a guest
            likes = json_data[i]['likes']
            dislikes = json_data[i]['dislikes']
            numReports = json_data[i]['numReports']

            data=[issue_name, message, author, likes, dislikes, numReports]
            append_me = pd.Series(data=data, index = df.columns)
            df = df.append(append_me, ignore_index=True) # Append the new Series into df
        
    return df

# %%
# NOT PART OF WEBSCRAPING PIPELINE
def scrape_single_issue(url, df=None):
    """
    Scrapes issue for a single url (e.g. "https://readcomiconline.to/Comic/The-Wild-Storm/Issue-4")
    Can be passed a df with some issues already scraped
    Returns a df with comments for single scraped issue
    """
    if df is None:
        df = pd.DataFrame(columns=['Webpage','Message', 'Author', 'Likes', 'Dislikes', 'NumReports'])
        print("new df created")

    else:
        print("df loaded")

#     driver = webdriver.Opera(executable_path='webdriver/operadriver_mac64/operadriver')
#     driver = webdriver.Chrome(executable_path='/Users/ari/Documents/Data Science Projects/Comic Comments NLP/webdriver/chromedriver')

    if url[33:] not in df['Webpage'].values: # If the webpage hasn't yet been scraped
        # RUN ALL FUNCTIONS
        try:
            print(f"Now scraping: {url[33:]}")
            soup = get_comment_soup(url)
            json_data = soup_to_json(soup)
            df = get_messages(df, url, json_data)
            df.to_csv('comic_comments/comic_comments.csv') # SAVE AFTER EVERY SUCCESSFUL ISSUE SCRAPE
        # IF WEBSCRAPING FAILS
        except:
            print(f"SCRAPING FAILED for {url}")
    driver.close()
            
    return df

# %% [markdown]
# ## 0.1 Webscrape comments for one issue

# %%
# SAMPLE SINGLE-ISSUE SCRAPING
url = "https://readcomiconline.to/Comic/The-Wild-Storm/Issue-4"
df_wild_issue = scrape_single_issue(url)
df_wild_issue
# Out:
# new df created
# Now scraping: The-Wild-Storm/Issue-4
# Disqus Threads elements: 1
# Num iframes:  3
# <!DOCTYPE html>
#
# <!--[if IE 8]><html lang="en" dir="ltr" class="ie8"><![endif]-->
# <!--[if IE 9]><html lang="en" dir="ltr" class="ie9"><![endif]-->
# <!--[if gt IE 9]><!--><html dir="ltr" lang="en"><!--<![endif]-->
# <head>
# <title>Disqus Comments</title>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <style>
#         .alert--warning {
#             border-radius: 3px;
#             padding: 10px 15px;
#             margin-bottom: 10px;
#             background-color: #FFE070;
#             color: #A47703;
#         }
#
#         .alert--warning a,
#         .alert--warning a:hover,
#         .alert--warning strong {
#             color: #A47703;
#             font-weight: bold;
#         }
#
#         .alert--error p,
#         .alert--warning p {
#             margin-top: 5px;
#             margin-bottom: 5px;
#         }
#
#         </style>
# <style>
#
#         html {
#             overflow: hidden;
#         }
#
#
#         #error {
#             display: none;
#         }
#
#         .clearfix:after {
#             content: "";
#             display: block;
#             height: 0;
#             clear: both;
#             visibility: hidden;
#         }
#
#
#     </style>
# </meta></head>
# <body>
# <div class="alert--error" id="error">
# <p>We were unable to load Disqus. If you are a moderator please see our <a href="https://docs.disqus.com/help/83/"> troubleshooting guide</a>. </p>
# </div>
# <script id="disqus-forumData" type="text/json">{"session":{"canModerate":false,"audienceSyncVerified":false,"mustVerify":false,"canReply":true,"mustVerifyEmail":false},"forum":{"aetBannerConfirmation":null,"founder":"130014786","twitterName":"","commentsLinkOne":"1 Comment","guidelines":null,"favicon":{"permalink":"https://disqus.com/api/forums/favicons/readcomiconline.jpg","cache":"//a.disquscdn.com/1557955473/images/favicon-default.png"},"commentsLinkZero":"0 Comments","disableDisqusBranding":false,"daysAlive":0,"createdAt":"2015-12-30T01:49:20.316256","category":"Entertainment","aetBannerEnabled":false,"aetBannerTitle":null,"raw_guidelines":null,"colorScheme":"auto","id":"readcomiconline","installCompleted":true,"moderatorBadgeText":"","commentPolicyText":null,"aetEnabled":false,"channel":null,"sort":4,"description":"","newPolicy":true,"raw_description":"","language":"en","adsReviewStatus":1,"pk":"3951304","forumCategory":{"date_added":"2016-01-28T01:54:31","id":4,"name":"Entertainment"},"permissions":{},"commentPolicyLink":null,"aetBannerDescription":null,"name":"readcomiconline","commentsLinkMultiple":"{num} Comments","settings":{"adsDRNativeEnabled":true,"disable3rdPartyTrackers":true,"adsVideoEnabled":true,"allowAnonPost":false,"ssoRequired":false,"unapproveLinks":true,"linkAffiliationEnabled":true,"adsProductLinksThumbnailsEnabled":true,"adsProductStoriesEnabled":true,"organicDiscoveryEnabled":true,"adsProductDisplayEnabled":true,"adsProductLinksEnabled":true,"threadReactionsEnabled":true,"adsEnabled":true,"adsPositionTopEnabled":true,"hasCustomAvatar":false,"adultContent":false,"allowAnonVotes":false,"adsProductVideoEnabled":true,"mustVerify":true,"gifPickerEnabled":false,"mustVerifyEmail":true,"audienceSyncEnabled":false,"mediaembedEnabled":false,"adsPositionBottomEnabled":true,"discoveryLocked":false,"validateAllPosts":false,"adsSettingsLocked":false,"isVIP":false,"adsPositionInthreadEnabled":false},"organizationId":2647132,"typeface":"auto","url":"","daysThreadAlive":0,"avatar":{"small":{"permalink":"https://disqus.com/api/forums/avatars/readcomiconline.jpg?size=32","cache":"//a.disquscdn.com/1557955473/images/noavatar32.png"},"large":{"permalink":"https://disqus.com/api/forums/avatars/readcomiconline.jpg?size=92","cache":"//a.disquscdn.com/1557955473/images/noavatar92.png"}},"signedUrl":""}}</script>
# <script id="disqus-threadData" type="text/json">{"cursor":{"hasPrev":false,"prev":null,"total":23,"hasNext":false,"next":"1:0:0"},"code":0,"response":{"lastModified":1555273578,"posts":[{"editableUntil":"2017-05-24T18:29:56","dislikes":0,"numReports":0,"likes":6,"message":"\u003cp>This is great writing. I don't like all the characters, in fact I am not sure I like anyone from the cast so far but they are real people with real qualities and flaws, not paper stand ins to flesh this out. How they managed that in such short space is something i do not understand. But I love it.\u003c/p>\u003cp>The art is consistently awesome.\u003c/p>\u003cp>Can. Not. Wait. For. Next. Issue.\u003c/p>","id":"3310771295","createdAt":"2017-05-17T18:29:56","author":{"username":"matejsojka","about":"","name":"Matej Sojka","disable3rdPartyTrackers":true,"isPowerContributor":false,"joinedAt":"2016-12-28T14:17:39","profileUrl":"https://disqus.com/by/matejsojka/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"236660761","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/matejsojka.jpg","cache":"https://c.disquscdn.com/uploads/users/23666/761/avatar32.jpg?1491493014"},"isCustom":true,"permalink":"https://disqus.com/api/users/avatars/matejsojka.jpg","cache":"https://c.disquscdn.com/uploads/users/23666/761/avatar92.jpg?1491493014","large":{"permalink":"https://disqus.com/api/users/avatars/matejsojka.jpg","cache":"https://c.disquscdn.com/uploads/users/23666/761/avatar92.jpg?1491493014"}}},"media":[],"isSpam":false,"hasMore":false,"isDeleted":false,"isDeletedByAuthor":false,"parent":null,"isApproved":true,"isFlagged":false,"raw_message":"This is great writing. I don't like all the characters, in fact I am not sure I like anyone from the cast so far but they are real people with real qualities and flaws, not paper stand ins to flesh this out. How they managed that in such short space is something i do not understand. But I love it.\n\nThe art is consistently awesome.\n\nCan. Not. Wait. For. Next. Issue.","isHighlighted":false,"canVote":false,"thread":"5825828862","forum":"readcomiconline","depth":0,"points":6,"moderationLabels":[],"isEdited":false,"sb":false},{"editableUntil":"2017-05-24T15:50:59","dislikes":0,"numReports":0,"likes":5,"message":"","id":"3310481170","createdAt":"2017-05-17T15:50:59","author":{"name":"Guest","url":"","profileUrl":"","emailHash":"","avatar":{"small":{"permalink":"//a.disquscdn.com/1557955473/images/noavatar32.png","cache":"//a.disquscdn.com/1557955473/images/noavatar32.png"},"large":{"permalink":"//a.disquscdn.com/1557955473/images/noavatar92.png","cache":"//a.disquscdn.com/1557955473/images/noavatar92.png"},"permalink":"//a.disquscdn.com/1557955473/images/noavatar92.png","cache":"//a.disquscdn.com/1557955473/images/noavatar92.png"},"signedUrl":"","isAnonymous":true},"media":[],"isSpam":false,"hasMore":false,"isDeleted":true,"isDeletedByAuthor":false,"parent":null,"isApproved":true,"isFlagged":false,"raw_message":"","isHighlighted":false,"canVote":false,"thread":"5825828862","forum":"readcomiconline","depth":0,"points":5,"moderationLabels":[],"isEdited":false,"sb":false},{"editableUntil":"2017-05-24T16:34:36","dislikes":0,"numReports":0,"likes":0,"message":"\u003cp>shame it's not yet confirmed to be part of the main universe\u003c/p>","id":"3310555551","createdAt":"2017-05-17T16:34:36","author":{"username":"kareematta","about":"","name":"Steelballfc","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2014-12-12T11:08:56","profileUrl":"https://disqus.com/by/kareematta/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"135397990","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/kareematta.jpg","cache":"https://c.disquscdn.com/uploads/users/13539/7990/avatar32.jpg?1545896670"},"isCustom":true,"permalink":"https://disqus.com/api/users/avatars/kareematta.jpg","cache":"https://c.d ...
# <div id="fixed-content"></div>
# <script id="disqus-urls" type="text/json">{
#     "root":"//disqus.com",
#     "next":"https://c.disquscdn.com/next/current/embed"
# }</script>
# <script>!function () {
#             var d = document;
#             var toH = d.head.appendChild.bind(d.head);
#
#             var v = window.location.href.match(/[#&?]version=([0-9a-f]{32})/);
#             var src = 'https://c.disquscdn.com/next/embed/lounge.load';
#             if (v)
#                 src += '.' + v[1];
#             src += '.js';
#
#             var s = d.createElement('script');
#             s.crossOrigin = 'anonymous';
#             s.id = 'bootstrap-script';
#             s.setAttribute('data-app', 'lounge');
#             s.src = src;
#             toH(s);
#
#             var m = d.createElement('meta');
#             m.setAttribute('http-equiv', 'Content-Security-Policy');
#             m.setAttribute('content', "script-src https:;");
#             toH(m);
#         }();</script>
# </body>
# </html>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-e62c2d84d42b> in <module>
#       1 # SAMPLE SINGLE-ISSUE SCRAPING
#       2 url = "https://readcomiconline.to/Comic/The-Wild-Storm/Issue-4"
# ----> 3 df_wild_issue = scrape_single_issue(url)
#       4 df_wild_issue
#
# <ipython-input-25-6dde927f2b2a> in scrape_single_issue(url, df)
#      27 #         except:
#      28 #             print(f"SCRAPING FAILED for {url}")
# ---> 29     driver.close()
#      30
#      31     return df
#
# NameError: name 'driver' is not defined

# %% [markdown]
# ## 0.2 Webscrape comic series

# %%
# SAMPLE SERIES SCRAPING (3 SHORT SERIES)
series_urls = ["https://readcomiconline.to/Comic/Exit-Stage-Left-The-Snagglepuss-Chronicles",\
              "https://readcomiconline.to/Comic/The-Lone-Ranger-2018",\
              "https://readcomiconline.to/Comic/Wonder-Twins"]
df = harvest(series_urls)
# Out:
# new df created
# Attempting to scrape https://readcomiconline.to/Comic/Exit-Stage-Left-The-Snagglepuss-Chronicles
# df loaded. df length: 0
# Now scraping: https://readcomiconline.to/Comic/Exit-Stage-Left-The-Snagglepuss-Chronicles/Issue-6
# Num iframes:  2
# <!DOCTYPE html>
#
# <!--[if IE 8]><html lang="en" dir="ltr" class="ie8"><![endif]-->
# <!--[if IE 9]><html lang="en" dir="ltr" class="ie9"><![endif]-->
# <!--[if gt IE 9]><!--><html dir="ltr" lang="en"><!--<![endif]-->
# <head>
# <title>Disqus Comments</title>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <style>
#         .alert--warning {
#             border-radius: 3px;
#             padding: 10px 15px;
#             margin-bottom: 10px;
#             background-color: #FFE070;
#             color: #A47703;
#         }
#
#         .alert--warning a,
#         .alert--warning a:hover,
#         .alert--warning strong {
#             color: #A47703;
#             font-weight: bold;
#         }
#
#         .alert--error p,
#         .alert--warning p {
#             margin-top: 5px;
#             margin-bottom: 5px;
#         }
#
#         </style>
# <style>
#
#         html {
#             overflow: hidden;
#         }
#
#
#         #error {
#             display: none;
#         }
#
#         .clearfix:after {
#             content: "";
#             display: block;
#             height: 0;
#             clear: both;
#             visibility: hidden;
#         }
#
#
#     </style>
# </meta></head>
# <body>
# <div class="alert--error" id="error">
# <p>We were unable to load Disqus. If you are a moderator please see our <a href="https://docs.disqus.com/help/83/"> troubleshooting guide</a>. </p>
# </div>
# <script id="disqus-forumData" type="text/json">{"session":{"canModerate":false,"audienceSyncVerified":false,"mustVerify":false,"canReply":true,"mustVerifyEmail":false},"forum":{"aetBannerConfirmation":null,"founder":"130014786","twitterName":"","commentsLinkOne":"1 Comment","guidelines":null,"favicon":{"permalink":"https://disqus.com/api/forums/favicons/readcomiconline.jpg","cache":"//a.disquscdn.com/1557955473/images/favicon-default.png"},"commentsLinkZero":"0 Comments","disableDisqusBranding":false,"daysAlive":0,"createdAt":"2015-12-30T01:49:20.316256","category":"Entertainment","aetBannerEnabled":false,"aetBannerTitle":null,"raw_guidelines":null,"colorScheme":"auto","id":"readcomiconline","installCompleted":true,"moderatorBadgeText":"","commentPolicyText":null,"aetEnabled":false,"channel":null,"sort":4,"description":"","newPolicy":true,"raw_description":"","language":"en","adsReviewStatus":1,"pk":"3951304","forumCategory":{"date_added":"2016-01-28T01:54:31","id":4,"name":"Entertainment"},"permissions":{},"commentPolicyLink":null,"aetBannerDescription":null,"name":"readcomiconline","commentsLinkMultiple":"{num} Comments","settings":{"adsDRNativeEnabled":true,"disable3rdPartyTrackers":true,"adsVideoEnabled":true,"allowAnonPost":false,"ssoRequired":false,"unapproveLinks":true,"linkAffiliationEnabled":true,"adsProductLinksThumbnailsEnabled":true,"adsProductStoriesEnabled":true,"organicDiscoveryEnabled":true,"adsProductDisplayEnabled":true,"adsProductLinksEnabled":true,"threadReactionsEnabled":true,"adsEnabled":true,"adsPositionTopEnabled":true,"hasCustomAvatar":false,"adultContent":false,"allowAnonVotes":false,"adsProductVideoEnabled":true,"mustVerify":true,"gifPickerEnabled":false,"mustVerifyEmail":true,"audienceSyncEnabled":false,"mediaembedEnabled":false,"adsPositionBottomEnabled":true,"discoveryLocked":false,"validateAllPosts":false,"adsSettingsLocked":false,"isVIP":false,"adsPositionInthreadEnabled":false},"organizationId":2647132,"typeface":"auto","url":"","daysThreadAlive":0,"avatar":{"small":{"permalink":"https://disqus.com/api/forums/avatars/readcomiconline.jpg?size=32","cache":"//a.disquscdn.com/1557955473/images/noavatar32.png"},"large":{"permalink":"https://disqus.com/api/forums/avatars/readcomiconline.jpg?size=92","cache":"//a.disquscdn.com/1557955473/images/noavatar92.png"}},"signedUrl":""}}</script>
# <script id="disqus-threadData" type="text/json">{"cursor":{"hasPrev":false,"prev":null,"total":5,"hasNext":false,"next":"1:0:0"},"code":0,"response":{"lastModified":1553223601,"posts":[{"editableUntil":"2018-06-13T19:39:43","dislikes":0,"numReports":0,"likes":8,"message":"\u003cp>Bitter sweet but still a very good ending and comic in general.\u003c/p>","id":"3933354887","createdAt":"2018-06-06T19:39:43","author":{"username":"dimitrisom","about":"","name":"Dimitri Som\u00e9","disable3rdPartyTrackers":true,"isPowerContributor":false,"joinedAt":"2017-06-03T19:09:46","profileUrl":"https://disqus.com/by/dimitrisom/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"253903090","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/dimitrisom.jpg","cache":"https://c.disquscdn.com/uploads/users/25390/3090/avatar32.jpg?1558511637"},"isCustom":true,"permalink":"https://disqus.com/api/users/avatars/dimitrisom.jpg","cache":"https://c.disquscdn.com/uploads/users/25390/3090/avatar92.jpg?1558511637","large":{"permalink":"https://disqus.com/api/users/avatars/dimitrisom.jpg","cache":"https://c.disquscdn.com/uploads/users/25390/3090/avatar92.jpg?1558511637"}}},"media":[],"isSpam":false,"hasMore":false,"isDeleted":false,"isDeletedByAuthor":false,"parent":null,"isApproved":true,"isFlagged":false,"raw_message":"Bitter sweet but still a very good ending and comic in general.","isHighlighted":false,"canVote":false,"thread":"6715736200","forum":"readcomiconline","depth":0,"points":8,"moderationLabels":[],"isEdited":false,"sb":false},{"editableUntil":"2018-06-13T22:39:30","dislikes":0,"numReports":0,"likes":4,"message":"\u003cp>A great story for a great character.\u003cbr>Thanks\u003c/p>","id":"3933581428","createdAt":"2018-06-06T22:39:30","author":{"username":"Anubis_Necromancer","about":"","name":"Anubis_Necromancer","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2011-04-09T01:07:15","profileUrl":"https://disqus.com/by/Anubis_Necromancer/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"8950581","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/Anubis_Necromancer.jpg","cache":"//a.disquscdn.com/1557955473/images/noavatar32.png"},"isCustom":false,"permalink":"https://disqus.com/api/users/avatars/Anubis_Necromancer.jpg","cache":"//a.disquscdn.com/1557955473/images/noavatar92.png","large":{"permalink":"https://disqus.com/api/users/avatars/Anubis_Necromancer.jpg","cache":"//a.disquscdn.com/1557955473/images/noavatar92.png"}}},"media":[],"isSpam":false,"hasMore":false,"isDeleted":false,"isDeletedByAuthor":false,"parent":null,"isApproved":true,"isFlagged":false,"raw_message":"A great story for a great character.\nThanks","isHighlighted":false,"canVote":false,"thread":"6715736200","forum":"readcomiconline","depth":0,"points":4,"moderationLabels":[],"isEdited":false,"sb":false},{"editableUntil":"2018-06-13T20:25:43","dislikes":0,"numReports":0,"likes":4,"message":"\u003cp>what a story. really enjoyed this comic\u003c/p>","id":"3933421599","createdAt":"2018-06-06T20:25:43","author":{"username":"capsloth","about":"","name":"capsloth","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2018-01-28T17:12:48","profileUrl":"https://disqus.com/by/capsloth/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"278449988","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/capsloth.jpg","cache":"//a.disquscdn.com/1557955473/images/noavatar32.png"},"isCustom":false,"permalink":"https://disqus.com/api/users/avatars/capsloth.jpg","cache":"//a.disquscdn.com/1557955473/images/noavatar92.png","large":{"permalink":"https://disqus.com/api/users/avatars/capsloth.jpg","cache":"//a.disquscdn.com/1557955473/images/noavatar92.png"}}},"media":[],"isSpam":false,"hasMore":false,"isDeleted":false,"isDeletedByAuthor":false,"parent":null,"isApproved": ...
# <div id="fixed-content"></div>
# <script id="disqus-urls" type="text/json">{
#     "root":"//disqus.com",
#     "next":"https://c.disquscdn.com/next/current/embed"
# }</script>
# <script>!function () {
#             var d = document;
#             var toH = d.head.appendChild.bind(d.head);
#
#             var v = window.location.href.match(/[#&?]version=([0-9a-f]{32})/);
#             var src = 'https://c.disquscdn.com/next/embed/lounge.load';
#             if (v)
#                 src += '.' + v[1];
#             src += '.js';
#
#             var s = d.createElement('script');
#             s.crossOrigin = 'anonymous';
#             s.id = 'bootstrap-script';
#             s.setAttribute('data-app', 'lounge');
#             s.src = src;
#             toH(s);
#
#             var m = d.createElement('meta');
#             m.setAttribute('http-equiv', 'Content-Security-Policy');
#             m.setAttribute('content', "script-src https:;");
#             toH(m);
#         }();</script>
# </body>
# </html>
#
# Now scraping: https://readcomiconline.to/Comic/Exit-Stage-Left-The-Snagglepuss-Chronicles/Issue-5
# Num iframes:  2
# <!DOCTYPE html>
#
# <!--[if IE 8]><html lang="en" dir="ltr" class="ie8"><![endif]-->
# <!--[if IE 9]><html lang="en" dir="ltr" class="ie9"><![endif]-->
# <!--[if gt IE 9]><!--><html dir="ltr" lang="en"><!--<![endif]-->
# <head>
# <title>Disqus Comments</title>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <style>
#         .alert--warning {
#             border-radius: 3px;
#             padding: 10px 15px;
#             margin-bottom: 10px;
#             background-color: #FFE070;
#             color: #A47703;
#         }
#
#         .alert--warning a,
#         .alert--warning a:hover,
#         .alert--warning strong {
#             color: #A47703;
#             font-weight: bold;
#         }
#
#         .alert--error p,
#         .alert--warning p {
#             margin-top: 5px;
#             margin-bottom: 5px;
#         }
#
#         </style>
# <style>
#
#         html {
#             overflow: hidden;
#         }
#
#
#         #error {
#             display: none;
#         }
#
#         .clearfix:after {
#             content: "";
#             display: block;
#             height: 0;
#             clear: both;
#             visibility: hidden;
#         }
#
#
#     </style>
# </meta></head>
# <body>
# <div class="alert--error" id="error">
# <p>We were unable to load Disqus. If you are a moderator please see our <a href="https://docs.disqus.com/help/83/"> troubleshooting guide</a>. </p>
# </div>
# <script id="disqus-forumData" type="text/json">{"session":{"canModerate":false,"audienceSyncVerified":false,"mustVerify":false,"canReply":true,"mustVerifyEmail":false},"forum":{"aetBannerConfirmation":null,"founder":"130014786","twitterName":"","commentsLinkOne":"1 Comment","guidelines":null,"favicon":{"permalink":"https://disqus.com/api/forums/favicons/readcomiconline.jpg","cache":"//a.disquscdn.com/1557955473/images/favicon-default.png"},"commentsLinkZero":"0 Comments","disableDisqusBranding":false,"daysAlive":0,"createdAt":"2015-12-30T01:49:20.316256","category":"Entertainment","aetBannerEnabled":false,"aetBannerTitle":null,"raw_guidelines":null,"colorScheme":"auto","id":"readcomiconline","installCompleted":true,"moderatorBadgeText":"","commentPolicyText":null,"aetEnabled":false,"channel":null,"sort":4,"description":"","newPolicy":true,"raw_description":"","language":"en","adsReviewStatus":1,"pk":"3951304","forumCategory":{"date_added":"2016-01-28T01:54:31","id":4,"name":"Entertainment"},"permissions":{},"commentPolicyLink":null,"aetBannerDescription":null,"name":"readcomiconline","commentsLinkMultiple":"{num} Comments","settings":{"adsDRNativeEnabled":true,"disable3rdPartyTrackers":true,"adsVideoEnabled":true,"allowAnonPost":false,"ssoRequired":false,"unapproveLinks":true,"linkAffiliationEnabled":true,"adsProductLinksThumbnailsEnabled":true,"adsProductStoriesEnabled":true,"organicDiscoveryEnabled":true,"adsProductDisplayEnabled":true,"adsProductLinksEnabled":true,"threadReactionsEnabled":true,"adsEnabled":true,"adsPositionTopEnabled":true,"hasCustomAvatar":false,"adultContent":false,"allowAnonVotes":false,"adsProductVideoEnabled":true,"mustVerify":true,"gifPickerEnabled":false,"mustVerifyEmail":true,"audienceSyncEnabled":false,"mediaembedEnabled":false,"adsPositionBottomEnabled":true,"discoveryLocked":false,"validateAllPosts":false,"adsSettingsLocked":false,"isVIP":false,"adsPositionInthreadEnabled":false},"organizationId":2647132,"typeface":"auto","url":"","daysThreadAlive":0,"avatar":{"small":{"permalink":"https://disqus.com/api/forums/avatars/readcomiconline.jpg?size=32","cache":"//a.disquscdn.com/1557955473/images/noavatar32.png"},"large":{"permalink":"https://disqus.com/api/forums/avatars/readcomiconline.jpg?size=92","cache":"//a.disquscdn.com/1557955473/images/noavatar92.png"}},"signedUrl":""}}</script>
# <script id="disqus-threadData" type="text/json">{"cursor":{"hasPrev":false,"prev":null,"total":2,"hasNext":false,"next":"1:0:0"},"code":0,"response":{"lastModified":1553552965,"posts":[{"editableUntil":"2018-05-09T13:24:06","dislikes":0,"numReports":0,"likes":7,"message":"\u003cp>Holy shit dude...\u003c/p>\u003cp>Huck is dead and S.P is avenging the hell out of him!\u003c/p>\u003cp>This is an amazing chapter!\u003c/p>","id":"3882375118","createdAt":"2018-05-02T13:24:06","author":{"username":"hassansalehboxwalla","about":"Illustrator","name":"Hassan Saleh Boxwalla","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2014-12-24T08:10:02","profileUrl":"https://disqus.com/by/hassansalehboxwalla/","url":"","location":"UAE","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"136800060","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/hassansalehboxwalla.jpg","cache":"https://c.disquscdn.com/uploads/users/13680/60/avatar32.jpg?1474960895"},"isCustom":true,"permalink":"https://disqus.com/api/users/avatars/hassansalehboxwalla.jpg","cache":"https://c.disquscdn.com/uploads/users/13680/60/avatar92.jpg?1474960895","large":{"permalink":"https://disqus.com/api/users/avatars/hassansalehboxwalla.jpg","cache":"https://c.disquscdn.com/uploads/users/13680/60/avatar92.jpg?1474960895"}}},"media":[],"isSpam":false,"hasMore":false,"isDeleted":false,"isDeletedByAuthor":false,"parent":null,"isApproved":true,"isFlagged":false,"raw_message":"Holy shit dude...\n\nHuck is dead and S.P is avenging the hell out of him!\n\nThis is an amazing chapter!","isHighlighted":false,"canVote":false,"thread":"6647277658","forum":"readcomiconline","depth":0,"points":7,"moderationLabels":[],"isEdited":false,"sb":false},{"editableUntil":"2018-05-11T18:44:45","dislikes":0,"numReports":0,"likes":1,"message":"\u003cp>Damn, this was awesome!\u003c/p>","id":"3886106041","createdAt":"2018-05-04T18:44:45","author":{"username":"johnnycharneca","about":"","name":"Johnny Charneca","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2015-01-31T21:11:34","profileUrl":"https://disqus.com/by/johnnycharneca/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"142276571","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/johnnycharneca.jpg","cache":"https://c.disquscdn.com/uploads/users/14227/6571/avatar32.jpg?1422738696"},"isCustom":true,"permalink":"https://disqus.com/api/users/avatars/johnnycharneca.jpg","cache":"https://c.disquscdn.com/uploads/users/14227/6571/avatar92.jpg?1422738696","large":{"permalink":"https://disqus.com/api/users/avatars/johnnycharneca.jpg","cache":"https://c.disquscdn.com/uploads/users/14227/6571/avatar92.jpg?1422738696"}}},"media":[],"isSpam":false,"hasMore":false,"isDeleted":false,"isDeletedByAuthor":false,"parent":null,"isApproved":true,"isFlagged":false,"raw_message":"Damn, this was awesome!","isHighlighted":false,"canVote":false,"thread":"6647277658","forum":"readcomiconline","depth":0,"points":1,"moderationLabels":[],"isEdited":false,"sb":false}],"thread":{"feed":"https://readcomiconline.disqus.com/exit_stage_left_the_snagglepuss_chronicles_issue_5_read_exit_stage_left_the_snagglepuss_chronicles_i/latest.rss","author":"130014786","dislikes":0,"likes":0,"message":"","ratingsEnabled":false,"isSpam":false,"isDeleted":false,"category":"4312901","clean_title":"Exit Stage Left: The Snagglepuss Chronicles Issue #5 - Read Exit Stage Left: The Snagglepuss Chronicles Issue #5 comic online in high quality","id":"6647277658","signedLink":"http://disq.us/?url=http%3A%2F%2Freadcomiconline.to%2FComic%2FExit-Stage-Left-The-Snagglepuss-Chronicles%2FIssue-5%3Fid%3D133808&key=14vt0DAPJbim5RsFioZc8g","createdAt":"2018-05-02T13:17:14","hasStreaming":false,"raw_message":"","isClosed":false,"link":"http://readcomiconline.to/Comic/Exit-Stage-Left-The-Snagglepuss-Chronicles/Issue-5?id=133808","slug":"exit_stage_left_the_snagglepuss_chr ...
# <div id="fixed-content"></div>
# <script id="disqus-urls" type="text/json">{
#     "root":"//disqus.com",
#     "next":"https://c.disquscdn.com/next/current/embed"
# }</script>
# <script>!function () {
#             var d = document;
#             var toH = d.head.appendChild.bind(d.head);
#
#             var v = window.location.href.match(/[#&?]version=([0-9a-f]{32})/);
#             var src = 'https://c.disquscdn.com/next/embed/lounge.load';
#             if (v)
#                 src += '.' + v[1];
#             src += '.js';
#
#             var s = d.createElement('script');
#             s.crossOrigin = 'anonymous';
#             s.id = 'bootstrap-script';
#             s.setAttribute('data-app', 'lounge');
#             s.src = src;
#             toH(s);
#
#             var m = d.createElement('meta');
#             m.setAttribute('http-equiv', 'Content-Security-Policy');
#             m.setAttribute('content', "script-src https:;");
#             toH(m);
#         }();</script>
# </body>
# </html>
#
# Now scraping: https://readcomiconline.to/Comic/Exit-Stage-Left-The-Snagglepuss-Chronicles/Issue-4
# Num iframes:  2
# <!DOCTYPE html>
#
# <!--[if IE 8]><html lang="en" dir="ltr" class="ie8"><![endif]-->
# <!--[if IE 9]><html lang="en" dir="ltr" class="ie9"><![endif]-->
# <!--[if gt IE 9]><!--><html dir="ltr" lang="en"><!--<![endif]-->
# <head>
# <title>Disqus Comments</title>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <style>
#         .alert--warning {
#             border-radius: 3px;
#             padding: 10px 15px;
#             margin-bottom: 10px;
#             background-color: #FFE070;
#             color: #A47703;
#         }
#
#         .alert--warning a,
#         .alert--warning a:hover,
#         .alert--warning strong {
#             color: #A47703;
#             font-weight: bold;
#         }
#
#         .alert--error p,
#         .alert--warning p {
#             margin-top: 5px;
#             margin-bottom: 5px;
#         }
#
#         </style>
# <style>
#
#         html {
#             overflow: hidden;
#         }
#
#
#         #error {
#             display: none;
#         }
#
#         .clearfix:after {
#             content: "";
#             display: block;
#             height: 0;
#             clear: both;
#             visibility: hidden;
#         }
#
#
#     </style>
# </meta></head>
# <body>
# <div class="alert--error" id="error">
# <p>We were unable to load Disqus. If you are a moderator please see our <a href="https://docs.disqus.com/help/83/"> troubleshooting guide</a>. </p>
# </div>
# <script id="disqus-forumData" type="text/json">{"session":{"canModerate":false,"audienceSyncVerified":false,"mustVerify":false,"canReply":true,"mustVerifyEmail":false},"forum":{"aetBannerConfirmation":null,"founder":"130014786","twitterName":"","commentsLinkOne":"1 Comment","guidelines":null,"favicon":{"permalink":"https://disqus.com/api/forums/favicons/readcomiconline.jpg","cache":"//a.disquscdn.com/1557955473/images/favicon-default.png"},"commentsLinkZero":"0 Comments","disableDisqusBranding":false,"daysAlive":0,"createdAt":"2015-12-30T01:49:20.316256","category":"Entertainment","aetBannerEnabled":false,"aetBannerTitle":null,"raw_guidelines":null,"colorScheme":"auto","id":"readcomiconline","installCompleted":true,"moderatorBadgeText":"","commentPolicyText":null,"aetEnabled":false,"channel":null,"sort":4,"description":"","newPolicy":true,"raw_description":"","language":"en","adsReviewStatus":1,"pk":"3951304","forumCategory":{"date_added":"2016-01-28T01:54:31","id":4,"name":"Entertainment"},"permissions":{},"commentPolicyLink":null,"aetBannerDescription":null,"name":"readcomiconline","commentsLinkMultiple":"{num} Comments","settings":{"adsDRNativeEnabled":true,"disable3rdPartyTrackers":true,"adsVideoEnabled":true,"allowAnonPost":false,"ssoRequired":false,"unapproveLinks":true,"linkAffiliationEnabled":true,"adsProductLinksThumbnailsEnabled":true,"adsProductStoriesEnabled":true,"organicDiscoveryEnabled":true,"adsProductDisplayEnabled":true,"adsProductLinksEnabled":true,"threadReactionsEnabled":true,"adsEnabled":true,"adsPositionTopEnabled":true,"hasCustomAvatar":false,"adultContent":false,"allowAnonVotes":false,"adsProductVideoEnabled":true,"mustVerify":true,"gifPickerEnabled":false,"mustVerifyEmail":true,"audienceSyncEnabled":false,"mediaembedEnabled":false,"adsPositionBottomEnabled":true,"discoveryLocked":false,"validateAllPosts":false,"adsSettingsLocked":false,"isVIP":false,"adsPositionInthreadEnabled":false},"organizationId":2647132,"typeface":"auto","url":"","daysThreadAlive":0,"avatar":{"small":{"permalink":"https://disqus.com/api/forums/avatars/readcomiconline.jpg?size=32","cache":"//a.disquscdn.com/1557955473/images/noavatar32.png"},"large":{"permalink":"https://disqus.com/api/forums/avatars/readcomiconline.jpg?size=92","cache":"//a.disquscdn.com/1557955473/images/noavatar92.png"}},"signedUrl":""}}</script>
# <script id="disqus-threadData" type="text/json">{"cursor":{"hasPrev":false,"prev":null,"total":4,"hasNext":false,"next":"1:0:0"},"code":0,"response":{"lastModified":1553483637,"posts":[{"editableUntil":"2018-04-14T07:46:40","dislikes":0,"numReports":0,"likes":1,"message":"\u003cp>aaah the classic \"values\" person being actually completely corrupt and being an hypocrite of his/her own problem. All to demonize anyone but himself.\u003c/p>","id":"3843123514","createdAt":"2018-04-07T07:46:40","author":{"username":"disqus_xBplXWvsuw","about":"","name":"CERO","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2013-06-03T04:14:05","profileUrl":"https://disqus.com/by/disqus_xBplXWvsuw/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"54244678","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/disqus_xBplXWvsuw.jpg","cache":"https://c.disquscdn.com/uploads/users/5424/4678/avatar32.jpg?1412528798"},"isCustom":true,"permalink":"https://disqus.com/api/users/avatars/disqus_xBplXWvsuw.jpg","cache":"https://c.disquscdn.com/uploads/users/5424/4678/avatar92.jpg?1412528798","large":{"permalink":"https://disqus.com/api/users/avatars/disqus_xBplXWvsuw.jpg","cache":"https://c.disquscdn.com/uploads/users/5424/4678/avatar92.jpg?1412528798"}}},"media":[],"isSpam":false,"hasMore":false,"isDeleted":false,"isDeletedByAuthor":false,"parent":null,"isApproved":true,"isFlagged":false,"raw_message":"aaah the classic \"values\" person being actually completely corrupt and being an hypocrite of his/her own problem. All to demonize anyone but himself.","isHighlighted":false,"canVote":false,"thread":"6595789485","forum":"readcomiconline","depth":0,"points":1,"moderationLabels":[],"isEdited":false,"sb":false},{"editableUntil":"2018-12-28T00:21:58","dislikes":0,"numReports":0,"likes":0,"message":"\u003cp>Is that the same woman that snagglepuss left or that someone else?\u003c/p>\u003cp>I feel bad for her, all she ever wanted was to be loved\u003c/p>","id":"4250515036","createdAt":"2018-12-21T00:21:58","author":{"username":"FuckWarframe","about":"","name":"Chris","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2017-03-20T11:25:31","profileUrl":"https://disqus.com/by/FuckWarframe/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"246124836","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/FuckWarframe.jpg","cache":"https://c.disquscdn.com/uploads/users/24612/4836/avatar32.jpg?1555039496"},"isCustom":true,"permalink":"https://disqus.com/api/users/avatars/FuckWarframe.jpg","cache":"https://c.disquscdn.com/uploads/users/24612/4836/avatar92.jpg?1555039496","large":{"permalink":"https://disqus.com/api/users/avatars/FuckWarframe.jpg","cache":"https://c.disquscdn.com/uploads/users/24612/4836/avatar92.jpg?1555039496"}}},"media":[],"isSpam":false,"hasMore":false,"isDeleted":false,"isDeletedByAuthor":false,"parent":null,"isApproved":true,"isFlagged":false,"raw_message":"Is that the same woman that snagglepuss left or that someone else?\n\nI feel bad for her, all she ever wanted was to be loved","isHighlighted":false,"canVote":false,"thread":"6595789485","forum":"readcomiconline","depth":0,"points":0,"moderationLabels":[],"isEdited":true,"sb":false},{"editableUntil":"2018-08-01T19:29:26","dislikes":0,"numReports":0,"likes":0,"message":"\u003cp>There once was a lady named Gloria\u003cbr>Who got humped by Sir Geoffrey DuMaurier\u003cbr>Then six other men\u003cbr>Then Sir Geoffrey again\u003cbr>Then the band at the Waldorf-Astoria\u003c/p>","id":"4006090958","createdAt":"2018-07-25T19:29:26","author":{"username":"elias_algorithm","about":"","name":"Elias Algorithm","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2018-02-11T17:16:43","profileUrl":"https://disqus.com/by/elias_algorithm/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false ...
# <div id="fixed-content"></div>
# <script id="disqus-urls" type="text/json">{
#     "root":"//disqus.com",
#     "next":"https://c.disquscdn.com/next/current/embed"
# }</script>
# <script>!function () {
#             var d = document;
#             var toH = d.head.appendChild.bind(d.head);
#
#             var v = window.location.href.match(/[#&?]version=([0-9a-f]{32})/);
#             var src = 'https://c.disquscdn.com/next/embed/lounge.load';
#             if (v)
#                 src += '.' + v[1];
#             src += '.js';
#
#             var s = d.createElement('script');
#             s.crossOrigin = 'anonymous';
#             s.id = 'bootstrap-script';
#             s.setAttribute('data-app', 'lounge');
#             s.src = src;
#             toH(s);
#
#             var m = d.createElement('meta');
#             m.setAttribute('http-equiv', 'Content-Security-Policy');
#             m.setAttribute('content', "script-src https:;");
#             toH(m);
#         }();</script>
# </body>
# </html>
#
# Now scraping: https://readcomiconline.to/Comic/Exit-Stage-Left-The-Snagglepuss-Chronicles/Issue-3
# Num iframes:  2
# <!DOCTYPE html>
#
# <!--[if IE 8]><html lang="en" dir="ltr" class="ie8"><![endif]-->
# <!--[if IE 9]><html lang="en" dir="ltr" class="ie9"><![endif]-->
# <!--[if gt IE 9]><!--><html dir="ltr" lang="en"><!--<![endif]-->
# <head>
# <title>Disqus Comments</title>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <style>
#         .alert--warning {
#             border-radius: 3px;
#             padding: 10px 15px;
#             margin-bottom: 10px;
#             background-color: #FFE070;
#             color: #A47703;
#         }
#
#         .alert--warning a,
#         .alert--warning a:hover,
#         .alert--warning strong {
#             color: #A47703;
#             font-weight: bold;
#         }
#
#         .alert--error p,
#         .alert--warning p {
#             margin-top: 5px;
#             margin-bottom: 5px;
#         }
#
#         </style>
# <style>
#
#         html {
#             overflow: hidden;
#         }
#
#
#         #error {
#             display: none;
#         }
#
#         .clearfix:after {
#             content: "";
#             display: block;
#             height: 0;
#             clear: both;
#             visibility: hidden;
#         }
#
#
#     </style>
# </meta></head>
# <body>
# <div class="alert--error" id="error">
# <p>We were unable to load Disqus. If you are a moderator please see our <a href="https://docs.disqus.com/help/83/"> troubleshooting guide</a>. </p>
# </div>
# <script id="disqus-forumData" type="text/json">{"session":{"canModerate":false,"audienceSyncVerified":false,"mustVerify":false,"canReply":true,"mustVerifyEmail":false},"forum":{"aetBannerConfirmation":null,"founder":"130014786","twitterName":"","commentsLinkOne":"1 Comment","guidelines":null,"favicon":{"permalink":"https://disqus.com/api/forums/favicons/readcomiconline.jpg","cache":"//a.disquscdn.com/1557955473/images/favicon-default.png"},"commentsLinkZero":"0 Comments","disableDisqusBranding":false,"daysAlive":0,"createdAt":"2015-12-30T01:49:20.316256","category":"Entertainment","aetBannerEnabled":false,"aetBannerTitle":null,"raw_guidelines":null,"colorScheme":"auto","id":"readcomiconline","installCompleted":true,"moderatorBadgeText":"","commentPolicyText":null,"aetEnabled":false,"channel":null,"sort":4,"description":"","newPolicy":true,"raw_description":"","language":"en","adsReviewStatus":1,"pk":"3951304","forumCategory":{"date_added":"2016-01-28T01:54:31","id":4,"name":"Entertainment"},"permissions":{},"commentPolicyLink":null,"aetBannerDescription":null,"name":"readcomiconline","commentsLinkMultiple":"{num} Comments","settings":{"adsDRNativeEnabled":true,"disable3rdPartyTrackers":true,"adsVideoEnabled":true,"allowAnonPost":false,"ssoRequired":false,"unapproveLinks":true,"linkAffiliationEnabled":true,"adsProductLinksThumbnailsEnabled":true,"adsProductStoriesEnabled":true,"organicDiscoveryEnabled":true,"adsProductDisplayEnabled":true,"adsProductLinksEnabled":true,"threadReactionsEnabled":true,"adsEnabled":true,"adsPositionTopEnabled":true,"hasCustomAvatar":false,"adultContent":false,"allowAnonVotes":false,"adsProductVideoEnabled":true,"mustVerify":true,"gifPickerEnabled":false,"mustVerifyEmail":true,"audienceSyncEnabled":false,"mediaembedEnabled":false,"adsPositionBottomEnabled":true,"discoveryLocked":false,"validateAllPosts":false,"adsSettingsLocked":false,"isVIP":false,"adsPositionInthreadEnabled":false},"organizationId":2647132,"typeface":"auto","url":"","daysThreadAlive":0,"avatar":{"small":{"permalink":"https://disqus.com/api/forums/avatars/readcomiconline.jpg?size=32","cache":"//a.disquscdn.com/1557955473/images/noavatar32.png"},"large":{"permalink":"https://disqus.com/api/forums/avatars/readcomiconline.jpg?size=92","cache":"//a.disquscdn.com/1557955473/images/noavatar92.png"}},"signedUrl":""}}</script>
# <script id="disqus-threadData" type="text/json">{"cursor":{"hasPrev":false,"prev":null,"total":2,"hasNext":false,"next":"1:0:0"},"code":0,"response":{"lastModified":1553244722,"posts":[{"editableUntil":"2018-03-15T04:53:52","dislikes":0,"numReports":0,"likes":2,"message":"\u003cp>Wow. This comic series continues to surprise me. It's a pleasure, even.\u003c/p>","id":"3792673975","createdAt":"2018-03-08T05:53:52","author":{"username":"jelyde1","about":"","name":"jelyde1","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2013-07-02T15:12:55","profileUrl":"https://disqus.com/by/jelyde1/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"60277249","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/jelyde1.jpg","cache":"https://c.disquscdn.com/uploads/users/6027/7249/avatar32.jpg?1372788850"},"isCustom":true,"permalink":"https://disqus.com/api/users/avatars/jelyde1.jpg","cache":"https://c.disquscdn.com/uploads/users/6027/7249/avatar92.jpg?1372788850","large":{"permalink":"https://disqus.com/api/users/avatars/jelyde1.jpg","cache":"https://c.disquscdn.com/uploads/users/6027/7249/avatar92.jpg?1372788850"}}},"media":[],"isSpam":false,"hasMore":false,"isDeleted":false,"isDeletedByAuthor":false,"parent":null,"isApproved":true,"isFlagged":false,"raw_message":"Wow. This comic series continues to surprise me. It's a pleasure, even.","isHighlighted":false,"canVote":false,"thread":"6530233728","forum":"readcomiconline","depth":0,"points":2,"moderationLabels":[],"isEdited":false,"sb":false},{"editableUntil":"2018-04-10T02:22:29","dislikes":0,"numReports":0,"likes":0,"message":"\u003cp>This comic is insanely deep!\u003c/p>","id":"3836484254","createdAt":"2018-04-03T02:22:29","author":{"username":"disqus_xBplXWvsuw","about":"","name":"CERO","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2013-06-03T04:14:05","profileUrl":"https://disqus.com/by/disqus_xBplXWvsuw/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"54244678","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/disqus_xBplXWvsuw.jpg","cache":"https://c.disquscdn.com/uploads/users/5424/4678/avatar32.jpg?1412528798"},"isCustom":true,"permalink":"https://disqus.com/api/users/avatars/disqus_xBplXWvsuw.jpg","cache":"https://c.disquscdn.com/uploads/users/5424/4678/avatar92.jpg?1412528798","large":{"permalink":"https://disqus.com/api/users/avatars/disqus_xBplXWvsuw.jpg","cache":"https://c.disquscdn.com/uploads/users/5424/4678/avatar92.jpg?1412528798"}}},"media":[],"isSpam":false,"hasMore":false,"isDeleted":false,"isDeletedByAuthor":false,"parent":null,"isApproved":true,"isFlagged":false,"raw_message":"This comic is insanely deep!","isHighlighted":false,"canVote":false,"thread":"6530233728","forum":"readcomiconline","depth":0,"points":0,"moderationLabels":[],"isEdited":false,"sb":false}],"thread":{"feed":"https://readcomiconline.disqus.com/exit_stage_left_the_snagglepuss_chronicles_issue_3_read_exit_stage_left_the_snagglepuss_chronicles_i/latest.rss","author":"130014786","dislikes":0,"likes":0,"message":"","ratingsEnabled":false,"isSpam":false,"isDeleted":false,"category":"4312901","clean_title":"Exit Stage Left: The Snagglepuss Chronicles Issue #3 - Read Exit Stage Left: The Snagglepuss Chronicles Issue #3 comic online in high quality","id":"6530233728","signedLink":"http://disq.us/?url=http%3A%2F%2Freadcomiconline.to%2FComic%2FExit-Stage-Left-The-Snagglepuss-Chronicles%2FIssue-3%3Fid%3D131662&key=B2rXnmbBOVGemHoWmaanWQ","createdAt":"2018-03-08T01:16:13","hasStreaming":false,"raw_message":"","isClosed":false,"link":"http://readcomiconline.to/Comic/Exit-Stage-Left-The-Snagglepuss-Chronicles/Issue-3?id=131662","slug":"exit_stage_left_the_snagglepuss_chronicles_issue_3_read_exit_stage_left_the_snagglepuss_chronicles_i","forum":"readcomiconline","identifiers":["e131662"],"posts":2,"moderators":[130014786,247086812],"valid ...
# <div id="fixed-content"></div>
# <script id="disqus-urls" type="text/json">{
#     "root":"//disqus.com",
#     "next":"https://c.disquscdn.com/next/current/embed"
# }</script>
# <script>!function () {
#             var d = document;
#             var toH = d.head.appendChild.bind(d.head);
#
#             var v = window.location.href.match(/[#&?]version=([0-9a-f]{32})/);
#             var src = 'https://c.disquscdn.com/next/embed/lounge.load';
#             if (v)
#                 src += '.' + v[1];
#             src += '.js';
#
#             var s = d.createElement('script');
#             s.crossOrigin = 'anonymous';
#             s.id = 'bootstrap-script';
#             s.setAttribute('data-app', 'lounge');
#             s.src = src;
#             toH(s);
#
#             var m = d.createElement('meta');
#             m.setAttribute('http-equiv', 'Content-Security-Policy');
#             m.setAttribute('content', "script-src https:;");
#             toH(m);
#         }();</script>
# </body>
# </html>
#
# Now scraping: https://readcomiconline.to/Comic/Exit-Stage-Left-The-Snagglepuss-Chronicles/Issue-2
# Num iframes:  2
# <!DOCTYPE html>
#
# <!--[if IE 8]><html lang="en" dir="ltr" class="ie8"><![endif]-->
# <!--[if IE 9]><html lang="en" dir="ltr" class="ie9"><![endif]-->
# <!--[if gt IE 9]><!--><html dir="ltr" lang="en"><!--<![endif]-->
# <head>
# <title>Disqus Comments</title>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <style>
#         .alert--warning {
#             border-radius: 3px;
#             padding: 10px 15px;
#             margin-bottom: 10px;
#             background-color: #FFE070;
#             color: #A47703;
#         }
#
#         .alert--warning a,
#         .alert--warning a:hover,
#         .alert--warning strong {
#             color: #A47703;
#             font-weight: bold;
#         }
#
#         .alert--error p,
#         .alert--warning p {
#             margin-top: 5px;
#             margin-bottom: 5px;
#         }
#
#         </style>
# <style>
#
#         html {
#             overflow: hidden;
#         }
#
#
#         #error {
#             display: none;
#         }
#
#         .clearfix:after {
#             content: "";
#             display: block;
#             height: 0;
#             clear: both;
#             visibility: hidden;
#         }
#
#
#     </style>
# </meta></head>
# <body>
# <div class="alert--error" id="error">
# <p>We were unable to load Disqus. If you are a moderator please see our <a href="https://docs.disqus.com/help/83/"> troubleshooting guide</a>. </p>
# </div>
# <script id="disqus-forumData" type="text/json">{"session":{"canModerate":false,"audienceSyncVerified":false,"mustVerify":false,"canReply":true,"mustVerifyEmail":false},"forum":{"aetBannerConfirmation":null,"founder":"130014786","twitterName":"","commentsLinkOne":"1 Comment","guidelines":null,"favicon":{"permalink":"https://disqus.com/api/forums/favicons/readcomiconline.jpg","cache":"//a.disquscdn.com/1557955473/images/favicon-default.png"},"commentsLinkZero":"0 Comments","disableDisqusBranding":false,"daysAlive":0,"createdAt":"2015-12-30T01:49:20.316256","category":"Entertainment","aetBannerEnabled":false,"aetBannerTitle":null,"raw_guidelines":null,"colorScheme":"auto","id":"readcomiconline","installCompleted":true,"moderatorBadgeText":"","commentPolicyText":null,"aetEnabled":false,"channel":null,"sort":4,"description":"","newPolicy":true,"raw_description":"","language":"en","adsReviewStatus":1,"pk":"3951304","forumCategory":{"date_added":"2016-01-28T01:54:31","id":4,"name":"Entertainment"},"permissions":{},"commentPolicyLink":null,"aetBannerDescription":null,"name":"readcomiconline","commentsLinkMultiple":"{num} Comments","settings":{"adsDRNativeEnabled":true,"disable3rdPartyTrackers":true,"adsVideoEnabled":true,"allowAnonPost":false,"ssoRequired":false,"unapproveLinks":true,"linkAffiliationEnabled":true,"adsProductLinksThumbnailsEnabled":true,"adsProductStoriesEnabled":true,"organicDiscoveryEnabled":true,"adsProductDisplayEnabled":true,"adsProductLinksEnabled":true,"threadReactionsEnabled":true,"adsEnabled":true,"adsPositionTopEnabled":true,"hasCustomAvatar":false,"adultContent":false,"allowAnonVotes":false,"adsProductVideoEnabled":true,"mustVerify":true,"gifPickerEnabled":false,"mustVerifyEmail":true,"audienceSyncEnabled":false,"mediaembedEnabled":false,"adsPositionBottomEnabled":true,"discoveryLocked":false,"validateAllPosts":false,"adsSettingsLocked":false,"isVIP":false,"adsPositionInthreadEnabled":false},"organizationId":2647132,"typeface":"auto","url":"","daysThreadAlive":0,"avatar":{"small":{"permalink":"https://disqus.com/api/forums/avatars/readcomiconline.jpg?size=32","cache":"//a.disquscdn.com/1557955473/images/noavatar32.png"},"large":{"permalink":"https://disqus.com/api/forums/avatars/readcomiconline.jpg?size=92","cache":"//a.disquscdn.com/1557955473/images/noavatar92.png"}},"signedUrl":""}}</script>
# <script id="disqus-threadData" type="text/json">{"cursor":{"hasPrev":false,"prev":null,"total":3,"hasNext":false,"next":"1:0:0"},"code":0,"response":{"lastModified":1553244030,"posts":[{"editableUntil":"2018-02-16T18:06:05","dislikes":0,"numReports":0,"likes":2,"message":"\u003cp>This feels like a toonified version of Trumbo.\u003c/p>\u003cp>Gods, I cant believe clowns like that person of the \"committee\" was allowed to gain power in such a way.\u003c/p>","id":"3750603836","createdAt":"2018-02-09T18:06:05","author":{"username":"disqus_xBplXWvsuw","about":"","name":"CERO","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2013-06-03T04:14:05","profileUrl":"https://disqus.com/by/disqus_xBplXWvsuw/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"54244678","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/disqus_xBplXWvsuw.jpg","cache":"https://c.disquscdn.com/uploads/users/5424/4678/avatar32.jpg?1412528798"},"isCustom":true,"permalink":"https://disqus.com/api/users/avatars/disqus_xBplXWvsuw.jpg","cache":"https://c.disquscdn.com/uploads/users/5424/4678/avatar92.jpg?1412528798","large":{"permalink":"https://disqus.com/api/users/avatars/disqus_xBplXWvsuw.jpg","cache":"https://c.disquscdn.com/uploads/users/5424/4678/avatar92.jpg?1412528798"}}},"media":[],"isSpam":false,"hasMore":false,"isDeleted":false,"isDeletedByAuthor":false,"parent":null,"isApproved":true,"isFlagged":false,"raw_message":"This feels like a toonified version of Trumbo.\n\nGods, I cant believe clowns like that person of the \"committee\" was allowed to gain power in such a way.","isHighlighted":false,"canVote":false,"thread":"6465385330","forum":"readcomiconline","depth":0,"points":2,"moderationLabels":[],"isEdited":false,"sb":false},{"editableUntil":"2018-06-01T06:01:00","dislikes":0,"numReports":0,"likes":1,"message":"\u003cp>I just realized GG Allen looks like Ayn Rand\u003c/p>","id":"3916459590","createdAt":"2018-05-25T06:01:00","author":{"username":"agostocarmes","about":"","name":"Agosto-Carmes\u00ed","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2018-04-19T19:23:08","profileUrl":"https://disqus.com/by/agostocarmes/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"285833490","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/agostocarmes.jpg","cache":"https://c.disquscdn.com/uploads/users/28583/3490/avatar32.jpg?1527228061"},"isCustom":true,"permalink":"https://disqus.com/api/users/avatars/agostocarmes.jpg","cache":"https://c.disquscdn.com/uploads/users/28583/3490/avatar92.jpg?1527228061","large":{"permalink":"https://disqus.com/api/users/avatars/agostocarmes.jpg","cache":"https://c.disquscdn.com/uploads/users/28583/3490/avatar92.jpg?1527228061"}}},"media":[],"isSpam":false,"hasMore":false,"isDeleted":false,"isDeletedByAuthor":false,"parent":null,"isApproved":true,"isFlagged":false,"raw_message":"I just realized GG Allen looks like Ayn Rand","isHighlighted":false,"canVote":false,"thread":"6465385330","forum":"readcomiconline","depth":0,"points":1,"moderationLabels":[],"isEdited":false,"sb":false},{"editableUntil":"2018-02-17T03:56:07","dislikes":0,"numReports":0,"likes":1,"message":"\u003cp>I'll admit.... Not only do I like the backup strip. I kinda think Tonya is cute. :)\u003c/p>","id":"3751326089","createdAt":"2018-02-10T03:56:07","author":{"username":"johnpaulguerra","about":"","name":"John Paul Guerra","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2015-05-20T08:46:01","profileUrl":"https://disqus.com/by/johnpaulguerra/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"158309239","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/johnpaulguerra.jpg","cache":"https://c.disquscdn.com/uploads/users/15830/9239/avatar32.jpg?1536541969"},"isCustom":true,"permalink":"https://disqus.com/api ...
# <div id="fixed-content"></div>
# <script id="disqus-urls" type="text/json">{
#     "root":"//disqus.com",
#     "next":"https://c.disquscdn.com/next/current/embed"
# }</script>
# <script>!function () {
#             var d = document;
#             var toH = d.head.appendChild.bind(d.head);
#
#             var v = window.location.href.match(/[#&?]version=([0-9a-f]{32})/);
#             var src = 'https://c.disquscdn.com/next/embed/lounge.load';
#             if (v)
#                 src += '.' + v[1];
#             src += '.js';
#
#             var s = d.createElement('script');
#             s.crossOrigin = 'anonymous';
#             s.id = 'bootstrap-script';
#             s.setAttribute('data-app', 'lounge');
#             s.src = src;
#             toH(s);
#
#             var m = d.createElement('meta');
#             m.setAttribute('http-equiv', 'Content-Security-Policy');
#             m.setAttribute('content', "script-src https:;");
#             toH(m);
#         }();</script>
# </body>
# </html>
#
# Now scraping: https://readcomiconline.to/Comic/Exit-Stage-Left-The-Snagglepuss-Chronicles/Issue-1
# Num iframes:  2
# <!DOCTYPE html>
#
# <!--[if IE 8]><html lang="en" dir="ltr" class="ie8"><![endif]-->
# <!--[if IE 9]><html lang="en" dir="ltr" class="ie9"><![endif]-->
# <!--[if gt IE 9]><!--><html dir="ltr" lang="en"><!--<![endif]-->
# <head>
# <title>Disqus Comments</title>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <style>
#         .alert--warning {
#             border-radius: 3px;
#             padding: 10px 15px;
#             margin-bottom: 10px;
#             background-color: #FFE070;
#             color: #A47703;
#         }
#
#         .alert--warning a,
#         .alert--warning a:hover,
#         .alert--warning strong {
#             color: #A47703;
#             font-weight: bold;
#         }
#
#         .alert--error p,
#         .alert--warning p {
#             margin-top: 5px;
#             margin-bottom: 5px;
#         }
#
#         </style>
# <style>
#
#         html {
#             overflow: hidden;
#         }
#
#
#         #error {
#             display: none;
#         }
#
#         .clearfix:after {
#             content: "";
#             display: block;
#             height: 0;
#             clear: both;
#             visibility: hidden;
#         }
#
#
#     </style>
# </meta></head>
# <body>
# <div class="alert--error" id="error">
# <p>We were unable to load Disqus. If you are a moderator please see our <a href="https://docs.disqus.com/help/83/"> troubleshooting guide</a>. </p>
# </div>
# ...
# <script id="disqus-threadData" type="text/json">{"cursor":{"hasPrev":false,"prev":null,"total":40,"hasNext":false,"next":"1:0:0"},"code":0,"response":{"lastModified":1558171320,"posts":[{"editableUntil":"2019-03-20T16:15:25","dislikes":0,"numReports":0,"likes":26,"message":"\u003cp>Damn, I feel bad for Drunkula\u003c/p>","id":"4376594329","createdAt":"2019-03-13T16:15:25","author":{"username":"MrRootbeer94","about":"","name":"Michael","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2015-11-15T15:41:58","profileUrl":"https://disqus.com/by/MrRootbeer94/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"182898971","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/MrRootbeer94.jpg","cache":"https://c.disquscdn.com/uploads/users/18289/8971/avatar32.jpg?1534212428"},"isCustom":true,"permalink":"https://disqus.com/api/users/avatars/MrRootbeer94.jpg","cache":"https://c.disquscdn.com/uploads/users/18289/8971/avatar92.jpg?1534212428","large":{"permalink":"https://disqus.com/api/users/avatars/MrRootbeer94.jpg","cache":"https://c.disquscdn.com/uploads/users/18289/8971/avatar92.jpg?1534212428"}}},"media":[],"isSpam":false,"hasMore":false,"isDeleted":false,"isDeletedByAuthor":false,"parent":null,"isApproved":true,"isFlagged":false,"raw_message":"Damn, I feel bad for Drunkula","isHighlighted":false,"canVote":false,"thread":"7291479796","forum":"readcomiconline","depth":0,"points":26,"moderationLabels":[],"isEdited":false,"sb":false},{"editableUntil":"2019-03-20T19:57:28","dislikes":0,"numReports":0,"likes":2,"message":"\u003cp>It made for such a bleak ending, he just wanted to get better \ud83d\ude2d. I wish Roy was still alive to be their Titan helper. Given his experience with the situation, he'd have handled it better. I blame Dick for not recruiting him, and King for killing him. Arsenal is turning in his grave \ud83d\ude2d\ud83d\ude2d\ud83d\ude2d\ud83d\ude2d\ud83d\ude2d!\u003c/p>","id":"4376977465","createdAt":"2019-03-13T19:57:28","author":{"username":"disqus_orjqd4oTwz","about":"","name":"THE Gentleman","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2017-09-10T18:32:03","profileUrl":"https://disqus.com/by/disqus_orjqd4oTwz/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"264776068","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/disqus_orjqd4oTwz.jpg","cache":"https://c.disquscdn.com/uploads/users/26477/6068/avatar32.jpg?1558520557"},"isCustom":true,"permalink":"https://disqus.com/api/users/avatars/disqus_orjqd4oTwz.jpg","cache":"https://c.disquscdn.com/uploads/users/26477/6068/avatar92.jpg?1558520557","large":{"permalink":"https://disqus.com/api/users/avatars/disqus_orjqd4oTwz.jpg","cache":"https://c.disquscdn.com/uploads/users/26477/6068/avatar92.jpg?1558520557"}}},"media":[],"isSpam":false,"hasMore":false,"isDeleted":false,"isDeletedByAuthor":false,"parent":4376594329,"isApproved":true,"isFlagged":false,"raw_message":"It made for such a bleak ending, he just wanted to get better \ud83d\ude2d. I wish Roy was still alive to be their Titan helper. Given his experience with the situation, he'd have handled it better. I blame Dick for not recruiting him, and King for killing him. Arsenal is turning in his grave \ud83d\ude2d\ud83d\ude2d\ud83d\ude2d\ud83d\ude2d\ud83d\ude2d!","isHighlighted":false,"canVote":false,"thread":"7291479796","forum":"readcomiconline","depth":1,"points":2,"moderationLabels":[],"isEdited":true,"sb":false},{"editableUntil":"2019-03-20T18:52:11","dislikes":0,"numReports":0,"likes":1,"message":"\u003cp>Like the rest of us he never wanted any of this.\u003c/p>","id":"4376862808","createdAt":"2019-03-13T18:52:11","author":{"username":"Bireus","about":"","name":"Bireus","disable3rdPartyTrackers":true,"isPowerContributor":false,"joinedAt":"2017-12-21T20:54:39","profileUrl":"https://disqus.com/by/Bireus/","url":"https://www.quora.com/pro ...
# <div id="fixed-content"></div>
# <script id="disqus-urls" type="text/json">{
#     "root":"//disqus.com",
#     "next":"https://c.disquscdn.com/next/current/embed"
# }</script>
# <script>!function () {
#             var d = document;
#             var toH = d.head.appendChild.bind(d.head);
#
#             var v = window.location.href.match(/[#&?]version=([0-9a-f]{32})/);
#             var src = 'https://c.disquscdn.com/next/embed/lounge.load';
#             if (v)
#                 src += '.' + v[1];
#             src += '.js';
#
#             var s = d.createElement('script');
#             s.crossOrigin = 'anonymous';
#             s.id = 'bootstrap-script';
#             s.setAttribute('data-app', 'lounge');
#             s.src = src;
#             toH(s);
#
#             var m = d.createElement('meta');
#             m.setAttribute('http-equiv', 'Content-Security-Policy');
#             m.setAttribute('content', "script-src https:;");
#             toH(m);
#         }();</script>
# </body>
# </html>
#
# Now scraping: https://readcomiconline.to/Comic/Wonder-Twins/Issue-1
# Num iframes:  2
# <!DOCTYPE html>
#
# <!--[if IE 8]><html lang="en" dir="ltr" class="ie8"><![endif]-->
# <!--[if IE 9]><html lang="en" dir="ltr" class="ie9"><![endif]-->
# <!--[if gt IE 9]><!--><html dir="ltr" lang="en"><!--<![endif]-->
# <head>
# <title>Disqus Comments</title>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <style>
#         .alert--warning {
#             border-radius: 3px;
#             padding: 10px 15px;
#             margin-bottom: 10px;
#             background-color: #FFE070;
#             color: #A47703;
#         }
#
#         .alert--warning a,
#         .alert--warning a:hover,
#         .alert--warning strong {
#             color: #A47703;
#             font-weight: bold;
#         }
#
#         .alert--error p,
#         .alert--warning p {
#             margin-top: 5px;
#             margin-bottom: 5px;
#         }
#
#         </style>
# <style>
#
#         html {
#             overflow: hidden;
#         }
#
#
#         #error {
#             display: none;
#         }
#
#         .clearfix:after {
#             content: "";
#             display: block;
#             height: 0;
#             clear: both;
#             visibility: hidden;
#         }
#
#
#     </style>
# </meta></head>
# <body>
# <div class="alert--error" id="error">
# <p>We were unable to load Disqus. If you are a moderator please see our <a href="https://docs.disqus.com/help/83/"> troubleshooting guide</a>. </p>
# </div>
# <script id="disqus-forumData" type="text/json">{"session":{"canModerate":false,"audienceSyncVerified":false,"mustVerify":false,"canReply":true,"mustVerifyEmail":false},"forum":{"aetBannerConfirmation":null,"founder":"130014786","twitterName":"","commentsLinkOne":"1 Comment","guidelines":null,"favicon":{"permalink":"https://disqus.com/api/forums/favicons/readcomiconline.jpg","cache":"//a.disquscdn.com/1557955473/images/favicon-default.png"},"commentsLinkZero":"0 Comments","disableDisqusBranding":false,"daysAlive":0,"createdAt":"2015-12-30T01:49:20.316256","category":"Entertainment","aetBannerEnabled":false,"aetBannerTitle":null,"raw_guidelines":null,"colorScheme":"auto","id":"readcomiconline","installCompleted":true,"moderatorBadgeText":"","commentPolicyText":null,"aetEnabled":false,"channel":null,"sort":4,"description":"","newPolicy":true,"raw_description":"","language":"en","adsReviewStatus":1,"pk":"3951304","forumCategory":{"date_added":"2016-01-28T01:54:31","id":4,"name":"Entertainment"},"permissions":{},"commentPolicyLink":null,"aetBannerDescription":null,"name":"readcomiconline","commentsLinkMultiple":"{num} Comments","settings":{"adsDRNativeEnabled":true,"disable3rdPartyTrackers":true,"adsVideoEnabled":true,"allowAnonPost":false,"ssoRequired":false,"unapproveLinks":true,"linkAffiliationEnabled":true,"adsProductLinksThumbnailsEnabled":true,"adsProductStoriesEnabled":true,"organicDiscoveryEnabled":true,"adsProductDisplayEnabled":true,"adsProductLinksEnabled":true,"threadReactionsEnabled":true,"adsEnabled":true,"adsPositionTopEnabled":true,"hasCustomAvatar":false,"adultContent":false,"allowAnonVotes":false,"adsProductVideoEnabled":true,"mustVerify":true,"gifPickerEnabled":false,"mustVerifyEmail":true,"audienceSyncEnabled":false,"mediaembedEnabled":false,"adsPositionBottomEnabled":true,"discoveryLocked":false,"validateAllPosts":false,"adsSettingsLocked":false,"isVIP":false,"adsPositionInthreadEnabled":false},"organizationId":2647132,"typeface":"auto","url":"","daysThreadAlive":0,"avatar":{"small":{"permalink":"https://disqus.com/api/forums/avatars/readcomiconline.jpg?size=32","cache":"//a.disquscdn.com/1557955473/images/noavatar32.png"},"large":{"permalink":"https://disqus.com/api/forums/avatars/readcomiconline.jpg?size=92","cache":"//a.disquscdn.com/1557955473/images/noavatar92.png"}},"signedUrl":""}}</script>
# <script id="disqus-threadData" type="text/json">{"cursor":{"hasPrev":false,"prev":null,"total":105,"hasNext":true,"next":"1:0:0"},"code":0,"response":{"lastModified":1558166598,"posts":[{"editableUntil":"2019-02-21T01:32:44","dislikes":0,"numReports":0,"likes":34,"message":"\u003cp>Mxy: \"Wait its not supposed to work like---\"\u003cbr>Our thoughts exactly mxy, our thoughts exactly\u003cbr>I am gonna make sure to check for a thunderstorm forecast before my next visit to Exxor.\u003c/p>","id":"4336638347","createdAt":"2019-02-14T01:32:44","author":{"username":"deadlycool","about":"I read comics from monday to saturday , and develop softwares on sundays.","name":"Dead Cool","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2018-11-22T16:33:50","profileUrl":"https://disqus.com/by/deadlycool/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"325427892","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/deadlycool.jpg","cache":"https://c.disquscdn.com/uploads/users/32542/7892/avatar32.jpg?1549312289"},"isCustom":true,"permalink":"https://disqus.com/api/users/avatars/deadlycool.jpg","cache":"https://c.disquscdn.com/uploads/users/32542/7892/avatar92.jpg?1549312289","large":{"permalink":"https://disqus.com/api/users/avatars/deadlycool.jpg","cache":"https://c.disquscdn.com/uploads/users/32542/7892/avatar92.jpg?1549312289"}}},"media":[],"isSpam":false,"hasMore":true,"isDeleted":false,"isDeletedByAuthor":false,"parent":null,"isApproved":true,"isFlagged":false,"raw_message":"Mxy: \"Wait its not supposed to work like---\"\nOur thoughts exactly mxy, our thoughts exactly\nI am gonna make sure to check for a thunderstorm forecast before my next visit to Exxor.","isHighlighted":false,"canVote":false,"thread":"7230974805","forum":"readcomiconline","depth":0,"points":34,"moderationLabels":[],"isEdited":false,"sb":false},{"editableUntil":"2019-02-21T07:19:36","dislikes":0,"numReports":0,"likes":14,"message":"\u003cp>Well Lex killed his crime syndicate doppelganger by saying Mazahs in the same voice, so apparently magic works on the \"close enough for government work\" principle.\u003c/p>","id":"4336910715","createdAt":"2019-02-14T07:19:36","author":{"username":"disqus_Ywn9YonV2V","about":"","name":"StSword","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2018-05-30T16:44:46","profileUrl":"https://disqus.com/by/disqus_Ywn9YonV2V/","url":"","location":"","isPrivate":false,"signedUrl":"","isPrimary":true,"isAnonymous":false,"id":"288939635","avatar":{"small":{"permalink":"https://disqus.com/api/users/avatars/disqus_Ywn9YonV2V.jpg","cache":"//a.disquscdn.com/1557955473/images/noavatar32.png"},"isCustom":false,"permalink":"https://disqus.com/api/users/avatars/disqus_Ywn9YonV2V.jpg","cache":"//a.disquscdn.com/1557955473/images/noavatar92.png","large":{"permalink":"https://disqus.com/api/users/avatars/disqus_Ywn9YonV2V.jpg","cache":"//a.disquscdn.com/1557955473/images/noavatar92.png"}}},"media":[],"isSpam":false,"hasMore":false,"isDeleted":false,"isDeletedByAuthor":false,"parent":4336638347,"isApproved":true,"isFlagged":false,"raw_message":"Well Lex killed his crime syndicate doppelganger by saying Mazahs in the same voice, so apparently magic works on the \"close enough for government work\" principle.","isHighlighted":false,"canVote":false,"thread":"7230974805","forum":"readcomiconline","depth":1,"points":14,"moderationLabels":[],"isEdited":false,"sb":false},{"editableUntil":"2019-02-21T02:09:20","dislikes":0,"numReports":0,"likes":3,"message":"\u003cp>who knows? it probably just needs his voice.\u003c/p>","id":"4336673225","createdAt":"2019-02-14T02:09:20","author":{"username":"lucasnbregamaia","about":"","name":"Lucas N\u00f3brega Maia","disable3rdPartyTrackers":false,"isPowerContributor":false,"joinedAt":"2015-05-21T02:56:03","profileUrl":"https://disqus.com/by/lucasnbregamaia/","url":"","location":"","isPrivate":false,"signedUrl":"","isP ...
# <div id="fixed-content"></div>
# <script id="disqus-urls" type="text/json">{
#     "root":"//disqus.com",
#     "next":"https://c.disquscdn.com/next/current/embed"
# }</script>
# <script>!function () {
#             var d = document;
#             var toH = d.head.appendChild.bind(d.head);
#
#             var v = window.location.href.match(/[#&?]version=([0-9a-f]{32})/);
#             var src = 'https://c.disquscdn.com/next/embed/lounge.load';
#             if (v)
#                 src += '.' + v[1];
#             src += '.js';
#
#             var s = d.createElement('script');
#             s.crossOrigin = 'anonymous';
#             s.id = 'bootstrap-script';
#             s.setAttribute('data-app', 'lounge');
#             s.src = src;
#             toH(s);
#
#             var m = d.createElement('meta');
#             m.setAttribute('http-equiv', 'Content-Security-Policy');
#             m.setAttribute('content', "script-src https:;");
#             toH(m);
#         }();</script>
# </body>
# </html>

# %%
get_issues("https://readcomiconline.to/Comic/The-Walking-Dead")
# Out:
# Get Issues: total issues found: 197
# ['https://readcomiconline.to/Comic/The-Walking-Dead/Issue-191?id=154788',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-190?id=152968',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-189?id=151094',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-188?id=149556',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-187?id=147511',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-186?id=145200',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-185?id=143227',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-184?id=140805',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-183?id=139244',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-182?id=137790',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-181?id=136477',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-180?id=135340',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-179?id=133832',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-178?id=132789',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-177?id=131648',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-176?id=130292',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-175?id=128046',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-174?id=126312',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-173?id=124423',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-172?id=122744',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-171?id=120886',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-170?id=118348',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-169?id=116370',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-168?id=114114',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-167?id=111098',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-166?id=109169',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-165?id=105586',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-164?id=104611',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-163?id=102665',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-162?id=99918',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-161?id=97863',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-160?id=94643',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-159?id=91684',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-158?id=86851',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-157?id=79529',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-156?id=71983',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-155?id=58826',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-154?id=49144',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-153?id=38607',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-152?id=23679',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-151?id=18348',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-150?id=13717',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-149?id=3702',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-148?id=1712',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-147?id=1776',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-146?id=1775',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-145?id=1774',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-144?id=1773',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-143?id=1772',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-142?id=1771',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-141?id=1770',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-140?id=1769',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-139?id=1767',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-138?id=1766',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-137?id=1765',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-136?id=1764',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-135?id=1763',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-134?id=1762',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-133?id=1761',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-132?id=1760',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-131?id=1759',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-130?id=1758',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-129?id=1756',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-128?id=1755',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-127?id=1754',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-126?id=1753',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-125?id=1752',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-124?id=1751',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-123?id=1750',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-122?id=1748',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-121?id=1746',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-120?id=1744',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-119?id=1740',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-118?id=1739',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-117?id=1737',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-116?id=1735',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-115?id=1734',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-114?id=1732',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-113?id=1731',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-112?id=1730',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-111?id=1729',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-110?id=1728',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-109?id=1726',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-108?id=1725',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-107?id=1724',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-106?id=1723',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-105?id=1722',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-104?id=1721',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-103?id=1720',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-102?id=1719',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-101?id=1718',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-100?id=1717',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-99?id=1869',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-98?id=1868',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-97?id=1867',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-96?id=1866',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-95?id=1865',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-94?id=1864',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-93?id=1863',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-92?id=1862',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-91?id=1861',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-90?id=1860',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-89?id=1858',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-88?id=1857',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-87?id=1856',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-86?id=1855',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-85?id=1854',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-84?id=1853',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-83?id=1852',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-82?id=1851',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-81?id=1850',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-80?id=1849',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-79?id=1847',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-78?id=1846',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-77?id=1845',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-76?id=1844',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-75?id=1843',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-74?id=1842',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-73?id=1841',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-72?id=1840',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-71?id=1839',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-70?id=1838',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-69?id=1836',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-68?id=1835',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-67?id=1834',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-66?id=1833',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-65?id=1832',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-64?id=1831',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-63?id=1830',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-62?id=1829',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-61?id=1828',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-60?id=1827',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-59?id=1825',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-58?id=1824',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-57?id=1823',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-56?id=1822',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-55?id=1821',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-54?id=1820',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-53?id=1819',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-52?id=1818',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-51?id=1817',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-50?id=1816',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-49?id=1814',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-48?id=1813',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-47?id=1812',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-46?id=1811',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-45?id=1810',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-44?id=1809',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-43?id=1808',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-42?id=1807',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-41?id=1806',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-40?id=1805',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-39?id=1803',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-38?id=1802',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-37?id=1801',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-36?id=1800',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-35?id=1799',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-34?id=1798',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-33?id=1797',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-32?id=1796',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-31?id=1795',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-30?id=1794',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-29?id=1792',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-28?id=1791',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-27?id=1790',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-26?id=1789',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-25?id=1788',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-24?id=1787',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-23?id=1786',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-22?id=1785',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-21?id=1784',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-20?id=1783',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-19?id=1781',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-18?id=1780',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-17?id=1779',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-16?id=1778',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-15?id=1777',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-14?id=1768',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-13?id=1757',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-12?id=1742',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-11?id=1727',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-10?id=1716',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-9?id=1859',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-8?id=1848',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-7?id=1837',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-6?id=1826',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-5?id=1815',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-4?id=1804',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-3?id=1793',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-2?id=1782',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Issue-1?id=1715',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Special-Tyreese-Special?id=79857',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Special-The-Governor-Special?id=2167',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Special-Michonne-Special?id=2166',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Special-1-10th-Anniversary-Edition?id=1870',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/Script-Book-01?id=105330',
#  'https://readcomiconline.to/Comic/The-Walking-Dead/All-Out-War-Artist-Proof-Edition?id=2239']

# %% [markdown]
# # 1. NLP: Sentiment Analysis on Comments

# %% [markdown]
# Let's use both Textblob, Vader to analyze the sentiment of each comment.

# %%
# LOAD NLP MODEL
# nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# ## 1.0 Functions

# %%
def add_nlp_columns(df):
    """
    Updates df - adds NLP columns if it doesn't already have them
    Returns None
    """

    if "Compound" not in df.columns: # CHECK IF COLUMNS ALREADY EXIST
    
        # ADD NLP COLUMNS
        df['Polarity'] = None
        df['Subjectivity'] = None
        df['Positive'] = None
        df['Negative'] = None
        df['Neutral'] = None
        df['Compound'] = None

    return None

# %%
def sentiment_analysis(csv_file_path="comic_comments/comic_comments.csv"):
    """
    Takes in a webscraped csv of comments (comments in "Message" column)
    Returns an updated df with TextBlob and Vader columns for each comment
    Writes the updated df to file
    """
    # LOAD COMMENTS DF
    df = pd.read_csv(csv_file_path, index_col='Unnamed: 0', encoding = "ISO-8859-1")
    
    # ADD SENTIMENT COLUMNS
    add_nlp_columns(df)
    
    # Instantiate Vader analyzer
    analyzer = SentimentIntensityAnalyzer()
    
    # DROP NaNs (blank/deleted comments )
    df.dropna(subset=['Message'], inplace=True)
    
    # FILL IN TextBlob COLUMNS,
    pol = lambda x: round(TextBlob(x).sentiment.polarity,3)
    sub = lambda x: round(TextBlob(x).sentiment.subjectivity,3)
    
    df['Polarity'] = df['Message'].apply(pol)
    df['Subjectivity'] = df['Message'].apply(sub)

    # FILL IN Vader COLUMNS
    pos = lambda x: round(analyzer.polarity_scores(x)['pos'],3)
    neg = lambda x: round(analyzer.polarity_scores(x)['neg'],3)
    neu = lambda x: round(analyzer.polarity_scores(x)['neu'],3)
    compound = lambda x: round(analyzer.polarity_scores(x)['compound'],3)

    df['Positive'] = df['Message'].apply(pos)
    df['Negative'] = df['Message'].apply(neg)    
    df['Neutral'] = df['Message'].apply(neu)
    df['Compound'] = df['Message'].apply(compound)

    
    # WRITE TO FILE
    df.to_csv(csv_file_path)
    print(f"Successfully performed sentiment analysis on {csv_file_path}")
    return df

# %% [markdown]
# ## 1.1 Sample sentiment analysis

# %% [markdown]
# Let's apply sentiment scores to comments for a scraped comic series

# %%
# CREATE AND FILL IN SENTIMENT COLUMNS
df_comments = sentiment_analysis(csv_file_path)
# Out:
# Successfully performed sentiment analysis on comic_comments/comic_comments.csv

# %% [markdown]
# Now let's visually analyze the results:

# %%
# PLOT RESULTS (TextBlob) - HISTOGRAMS
x = df_comments['Polarity'].values
y = df_comments['Subjectivity'].values

# plt.rcParams['figure.figsize']=[12,10]
# plt.subplot(1,2,1)
# plt

f, ax = plt.subplots(1,2, figsize=(10,8), sharey=True)
ax[0].hist(x, bins=15)
ax[1].hist(y, bins=15)
plt.show();

## IMPROVE SUBPLOTS

# %%
# PLOT RESULTS (TextBlob) - SCATTERPLOT, subjectivity vs. polarity
plt.figure(figsize=(8,8))
plt.scatter(x, y, marker='o', color = 'red', alpha=0.2)
plt.show();

# %% [markdown]
# # 2. Set up, run webscraping pipeline

# %% [markdown]
# Scrape, make csvs, and run NLP for most popular comics

# %% [markdown]
# ### 2.1 Scrape the most popular comics

# %%
# GET A LIST OF THE MOST POPULAR SERIES
url = "https://readcomiconline.to/ComicList/MostPopular"
# driver = webdriver.Opera(executable_path='webdriver/operadriver_mac64/operadriver')

popular_series = get_issues(url)
popular_series = [series for series in popular_series if "?" not in series]
print(popular_series)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-eb2a8e68e988> in <module>
#       3 # driver = webdriver.Opera(executable_path='webdriver/operadriver_mac64/operadriver')
#       4
# ----> 5 popular_series = get_issues(url)
#       6 popular_series = [series for series in popular_series if "?" not in series]
#       7 print(popular_series)
#
# <ipython-input-3-bf89e15d89d9> in get_issues(series_homepage)
#      16     # GET LIST OF issue_urls
#      17     issue_table = driver.find_element_by_class_name("listing")
# ---> 18     all_issues = issue_table.find_elements_by_tag_name("a")
#      19     issue_urls = [issue.get_attribute("href") for issue in all_issues]
#      20     print(f"Get Issues: total issues found: {len(issue_urls)}")
#
# AttributeError: 'NoneType' object has no attribute 'find_elements_by_tag_name'

# %%
# MOST RECENT POPULAR_SERIES
popular_series = ['https://readcomiconline.to/Comic/The-Amazing-Spider-Man-1963', 'https://readcomiconline.to/Comic/Ultimate-Spider-Man-2000', 'https://readcomiconline.to/Comic/Saga', 'https://readcomiconline.to/Comic/The-Flash-2016', 'https://readcomiconline.to/Comic/Invincible', 'https://readcomiconline.to/Comic/Injustice-Gods-Among-Us-Year-Five', 'https://readcomiconline.to/Comic/Injustice-Gods-Among-Us-I', 'https://readcomiconline.to/Comic/Darth-Vader-2017', 'https://readcomiconline.to/Comic/Detective-Comics-2016', 'https://readcomiconline.to/Comic/W-i-t-c-h', 'https://readcomiconline.to/Comic/Rick-and-Morty', 'https://readcomiconline.to/Comic/Uncanny-X-Men-1963', 'https://readcomiconline.to/Comic/Sonic-The-Hedgehog', 'https://readcomiconline.to/Comic/Fables', 'https://readcomiconline.to/Comic/Red-Hood-and-the-Outlaws-2016', 'https://readcomiconline.to/Comic/Nightwing-2016', 'https://readcomiconline.to/Comic/Superman-2016', 'https://readcomiconline.to/Comic/Teen-Titans-2016', 'https://readcomiconline.to/Comic/Crossed-Badlands', 'https://readcomiconline.to/Comic/Justice-League', 'https://readcomiconline.to/Comic/Justice-League-2016', 'https://readcomiconline.to/Comic/Spawn', 'https://readcomiconline.to/Comic/Spider-Man-Deadpool', 'https://readcomiconline.to/Comic/The-Amazing-Spider-Man-2015', 'https://readcomiconline.to/Comic/Action-Comics-2016', 'https://readcomiconline.to/Comic/Old-Man-Logan-2016', 'https://readcomiconline.to/Comic/Titans-2016', 'https://readcomiconline.to/Comic/Injustice-Gods-Among-Us-Year-Two', 'https://readcomiconline.to/Comic/Preacher', 'https://readcomiconline.to/Comic/Injustice-Gods-Among-Us-Year-Three', 'https://readcomiconline.to/Comic/The-Boys', 'https://readcomiconline.to/Comic/Injustice-Gods-Among-Us-Year-Four', 'https://readcomiconline.to/Comic/Batman-1940', 'https://readcomiconline.to/Comic/Dark-Nights-Metal', 'https://readcomiconline.to/Comic/Mighty-Morphin-Power-Rangers', 'https://readcomiconline.to/Comic/Star-Wars-2015', 'https://readcomiconline.to/Comic/Injustice-Ground-Zero', 'https://readcomiconline.to/Comic/The-Sandman-1989', 'https://readcomiconline.to/Comic/Wonder-Woman-2016', 'https://readcomiconline.to/Comic/Doomsday-Clock', 'https://readcomiconline.to/Comic/Deadpool-2016', 'https://readcomiconline.to/Comic/Batman-2011', 'https://readcomiconline.to/Comic/The-Amazing-Spider-Man-2018', 'https://readcomiconline.to/Comic/Super-Sons', 'https://readcomiconline.to/Comic/Hal-Jordan-And-The-Green-Lantern-Corps', 'https://readcomiconline.to/Comic/Spider-Man-2016', 'https://readcomiconline.to/Comic/Darth-Vader']
current_series = ['https://readcomiconline.to/Comic/The-Amazing-Spider-Man-1963']

# %%
# LOAD A CSV FILE TO A DF (IF NEEDED)
csv_file_path = "comic_comments/comic_comments.csv"
loaded_df = pd.read_csv(csv_file_path, index_col='Unnamed: 0', encoding = "ISO-8859-1")
len(loaded_df)
# Out:
# 6397

# %%
# SCRAPE ALL ISSUES FOR EVERY SERIES IN popular_series - takes in a loaded_df
# df = harvest(popular_series, df=loaded_df)

# SCRAPE INDIVIDUAL SERIES
df = harvest(current_series, df=loaded_df)
# Out:
# df loaded. df length: 6397
# Scrape_series initaiated for https://readcomiconline.to/Comic/The-Amazing-Spider-Man-1963
# df loaded. df length: 6397
# Get Issues: total issues found: 705
# Scrape_series: 705 issues found for https://readcomiconline.to/Comic/The-Amazing-Spider-Man-1963
# The-Amazing-Spider-Man-1963/Issue-801 already scraped.
# The-Amazing-Spider-Man-1963/Issue-800 already scraped.
# The-Amazing-Spider-Man-1963/Issue-799 already scraped.
# The-Amazing-Spider-Man-1963/Issue-798 already scraped.
# The-Amazing-Spider-Man-1963/Issue-797 already scraped.
# The-Amazing-Spider-Man-1963/Issue-796 already scraped.
# The-Amazing-Spider-Man-1963/Issue-795 already scraped.
# The-Amazing-Spider-Man-1963/Issue-794 already scraped.
# The-Amazing-Spider-Man-1963/Issue-793 already scraped.
# The-Amazing-Spider-Man-1963/Issue-792 already scraped.
# The-Amazing-Spider-Man-1963/Issue-791 already scraped.
# The-Amazing-Spider-Man-1963/Issue-790 already scraped.
# The-Amazing-Spider-Man-1963/Issue-789 already scraped.
# The-Amazing-Spider-Man-1963/Issue-700-5 already scraped.
# The-Amazing-Spider-Man-1963/Issue-700-4 already scraped.
# The-Amazing-Spider-Man-1963/Issue-700-3 already scraped.
# The-Amazing-Spider-Man-1963/Issue-700-2 already scraped.
# The-Amazing-Spider-Man-1963/Issue-700-1 already scraped.
# The-Amazing-Spider-Man-1963/Issue-700 already scraped.
# The-Amazing-Spider-Man-1963/Issue-699-1 already scraped.
# The-Amazing-Spider-Man-1963/Issue-699 already scraped.
# The-Amazing-Spider-Man-1963/Issue-698 already scraped.
# The-Amazing-Spider-Man-1963/Issue-697 already scraped.
# The-Amazing-Spider-Man-1963/Issue-696 already scraped.
# The-Amazing-Spider-Man-1963/Issue-695 already scraped.
# The-Amazing-Spider-Man-1963/Issue-694 already scraped.
# The-Amazing-Spider-Man-1963/Issue-693 already scraped.
# The-Amazing-Spider-Man-1963/Issue-692 already scraped.
# The-Amazing-Spider-Man-1963/Issue-691 already scraped.
# The-Amazing-Spider-Man-1963/Issue-690 already scraped.
# The-Amazing-Spider-Man-1963/Issue-689 already scraped.
# The-Amazing-Spider-Man-1963/Issue-688 already scraped.
# The-Amazing-Spider-Man-1963/Issue-687 already scraped.
# The-Amazing-Spider-Man-1963/Issue-686 already scraped.
# The-Amazing-Spider-Man-1963/Issue-685 already scraped.
# The-Amazing-Spider-Man-1963/Issue-684 already scraped.
# The-Amazing-Spider-Man-1963/Issue-683 already scraped.
# The-Amazing-Spider-Man-1963/Issue-682 already scraped.
# The-Amazing-Spider-Man-1963/Issue-681 already scraped.
# The-Amazing-Spider-Man-1963/Issue-680 already scraped.
# The-Amazing-Spider-Man-1963/Issue-679-1 already scraped.
# The-Amazing-Spider-Man-1963/Issue-679 already scraped.
# The-Amazing-Spider-Man-1963/Issue-678 already scraped.
# The-Amazing-Spider-Man-1963/Issue-677 already scraped.
# The-Amazing-Spider-Man-1963/Issue-676 already scraped.
# The-Amazing-Spider-Man-1963/Issue-675 already scraped.
# The-Amazing-Spider-Man-1963/Issue-674 already scraped.
# The-Amazing-Spider-Man-1963/Issue-673 already scraped.
# The-Amazing-Spider-Man-1963/Issue-672 already scraped.
# The-Amazing-Spider-Man-1963/Issue-671 already scraped.
# The-Amazing-Spider-Man-1963/Issue-670 already scraped.
# The-Amazing-Spider-Man-1963/Issue-669 already scraped.
# The-Amazing-Spider-Man-1963/Issue-668 already scraped.
# The-Amazing-Spider-Man-1963/Issue-667 already scraped.
# The-Amazing-Spider-Man-1963/Issue-666 already scraped.
# The-Amazing-Spider-Man-1963/Issue-665 already scraped.
# The-Amazing-Spider-Man-1963/Issue-664 already scraped.
# The-Amazing-Spider-Man-1963/Issue-663 already scraped.
# The-Amazing-Spider-Man-1963/Issue-662 already scraped.
# The-Amazing-Spider-Man-1963/Issue-661 already scraped.
# The-Amazing-Spider-Man-1963/Issue-660 already scraped.
# The-Amazing-Spider-Man-1963/Issue-659 already scraped.
# The-Amazing-Spider-Man-1963/Issue-658 already scraped.
# The-Amazing-Spider-Man-1963/Issue-657 already scraped.
# The-Amazing-Spider-Man-1963/Issue-656 already scraped.
# The-Amazing-Spider-Man-1963/Issue-655 already scraped.
# The-Amazing-Spider-Man-1963/Issue-654-1 already scraped.
# The-Amazing-Spider-Man-1963/Issue-654 already scraped.
# The-Amazing-Spider-Man-1963/Issue-653 already scraped.
# The-Amazing-Spider-Man-1963/Issue-652 already scraped.
# The-Amazing-Spider-Man-1963/Issue-651 already scraped.
# The-Amazing-Spider-Man-1963/Issue-650 already scraped.
# The-Amazing-Spider-Man-1963/Issue-649 already scraped.
# The-Amazing-Spider-Man-1963/Issue-648 already scraped.
# The-Amazing-Spider-Man-1963/Issue-647 already scraped.
# The-Amazing-Spider-Man-1963/Issue-646 already scraped.
# The-Amazing-Spider-Man-1963/Issue-645 already scraped.
# The-Amazing-Spider-Man-1963/Issue-644 already scraped.
# The-Amazing-Spider-Man-1963/Issue-643 already scraped.
# The-Amazing-Spider-Man-1963/Issue-642 already scraped.
# The-Amazing-Spider-Man-1963/Issue-641 already scraped.
# The-Amazing-Spider-Man-1963/Issue-640 already scraped.
# The-Amazing-Spider-Man-1963/Issue-639 already scraped.
# The-Amazing-Spider-Man-1963/Issue-638 already scraped.
# The-Amazing-Spider-Man-1963/Issue-637 already scraped.
# The-Amazing-Spider-Man-1963/Issue-636 already scraped.
# The-Amazing-Spider-Man-1963/Issue-635 already scraped.
# The-Amazing-Spider-Man-1963/Issue-634 already scraped.
# The-Amazing-Spider-Man-1963/Issue-633 already scraped.
# The-Amazing-Spider-Man-1963/Issue-632 already scraped.
# The-Amazing-Spider-Man-1963/Issue-631 already scraped.
# The-Amazing-Spider-Man-1963/Issue-630 already scraped.
# The-Amazing-Spider-Man-1963/Issue-629 already scraped.
# The-Amazing-Spider-Man-1963/Issue-628 already scraped.
# The-Amazing-Spider-Man-1963/Issue-627 already scraped.
# The-Amazing-Spider-Man-1963/Issue-626 already scraped.
# The-Amazing-Spider-Man-1963/Issue-625 already scraped.
# The-Amazing-Spider-Man-1963/Issue-624 already scraped.
# The-Amazing-Spider-Man-1963/Issue-623 already scraped.
# The-Amazing-Spider-Man-1963/Issue-622 already scraped.
# The-Amazing-Spider-Man-1963/Issue-621 already scraped.
# The-Amazing-Spider-Man-1963/Issue-620 already scraped.
# The-Amazing-Spider-Man-1963/Issue-619 already scraped.
# The-Amazing-Spider-Man-1963/Issue-618 already scraped.
# The-Amazing-Spider-Man-1963/Issue-617 already scraped.
# The-Amazing-Spider-Man-1963/Issue-616 already scraped.
# The-Amazing-Spider-Man-1963/Issue-615 already scraped.
# The-Amazing-Spider-Man-1963/Issue-614 already scraped.
# The-Amazing-Spider-Man-1963/Issue-613 already scraped.
# The-Amazing-Spider-Man-1963/Issue-612 already scraped.
# The-Amazing-Spider-Man-1963/Issue-611 already scraped.
# The-Amazing-Spider-Man-1963/Issue-610 already scraped.
# The-Amazing-Spider-Man-1963/Issue-609 already scraped.
# The-Amazing-Spider-Man-1963/Issue-608 already scraped.
# The-Amazing-Spider-Man-1963/Issue-607 already scraped.
# The-Amazing-Spider-Man-1963/Issue-606 already scraped.
# The-Amazing-Spider-Man-1963/Issue-605 already scraped.
# The-Amazing-Spider-Man-1963/Issue-604 already scraped.
# The-Amazing-Spider-Man-1963/Issue-603 already scraped.
# The-Amazing-Spider-Man-1963/Issue-602 already scraped.
# The-Amazing-Spider-Man-1963/Issue-601 already scraped.
# The-Amazing-Spider-Man-1963/Issue-600 already scraped.
# The-Amazing-Spider-Man-1963/Issue-599 already scraped.
# The-Amazing-Spider-Man-1963/Issue-598 already scraped.
# The-Amazing-Spider-Man-1963/Issue-597 already scraped.
# The-Amazing-Spider-Man-1963/Issue-596 already scraped.
# The-Amazing-Spider-Man-1963/Issue-595 already scraped.
# The-Amazing-Spider-Man-1963/Issue-594 already scraped.
# The-Amazing-Spider-Man-1963/Issue-593 already scraped.
# The-Amazing-Spider-Man-1963/Issue-592 already scraped.
# The-Amazing-Spider-Man-1963/Issue-591 already scraped.
# The-Amazing-Spider-Man-1963/Issue-590 already scraped.
# The-Amazing-Spider-Man-1963/Issue-589 already scraped.
# The-Amazing-Spider-Man-1963/Issue-588 already scraped.
# The-Amazing-Spider-Man-1963/Issue-587 already scraped.
# The-Amazing-Spider-Man-1963/Issue-586 already scraped.
# The-Amazing-Spider-Man-1963/Issue-585 already scraped.
# The-Amazing-Spider-Man-1963/Issue-584 already scraped.
# The-Amazing-Spider-Man-1963/Issue-583 already scraped.
# The-Amazing-Spider-Man-1963/Issue-582 already scraped.
# The-Amazing-Spider-Man-1963/Issue-581 already scraped.
# The-Amazing-Spider-Man-1963/Issue-580 already scraped.
# The-Amazing-Spider-Man-1963/Issue-579 already scraped.
# The-Amazing-Spider-Man-1963/Issue-578 already scraped.
# The-Amazing-Spider-Man-1963/Issue-577 already scraped.
# The-Amazing-Spider-Man-1963/Issue-576 already scraped.
# The-Amazing-Spider-Man-1963/Issue-575 already scraped.
# The-Amazing-Spider-Man-1963/Issue-574 already scraped.
# The-Amazing-Spider-Man-1963/Issue-573 already scraped.
# The-Amazing-Spider-Man-1963/Issue-572 already scraped.
# The-Amazing-Spider-Man-1963/Issue-571 already scraped.
# The-Amazing-Spider-Man-1963/Issue-570 already scraped.
# The-Amazing-Spider-Man-1963/Issue-569 already scraped.
# The-Amazing-Spider-Man-1963/Issue-568 already scraped.
# The-Amazing-Spider-Man-1963/Issue-567 already scraped.
# The-Amazing-Spider-Man-1963/Issue-566 already scraped.
# The-Amazing-Spider-Man-1963/Issue-565 already scraped.
# The-Amazing-Spider-Man-1963/Issue-564 already scraped.
# The-Amazing-Spider-Man-1963/Issue-563 already scraped.
# The-Amazing-Spider-Man-1963/Issue-562 already scraped.
# The-Amazing-Spider-Man-1963/Issue-561 already scraped.
# The-Amazing-Spider-Man-1963/Issue-560 already scraped.
# The-Amazing-Spider-Man-1963/Issue-559 already scraped.
# The-Amazing-Spider-Man-1963/Issue-558 already scraped.
# The-Amazing-Spider-Man-1963/Issue-557 already scraped.
# The-Amazing-Spider-Man-1963/Issue-556 already scraped.
# The-Amazing-Spider-Man-1963/Issue-555 already scraped.
# The-Amazing-Spider-Man-1963/Issue-554 already scraped.
# Now scraping: https://readcomiconline.to/Comic/The-Amazing-Spider-Man-1963/Issue-553
# Total issues scraped: 1
# The-Amazing-Spider-Man-1963/Issue-552 already scraped.
# The-Amazing-Spider-Man-1963/Issue-551 already scraped.
# The-Amazing-Spider-Man-1963/Issue-550 already scraped.
# The-Amazing-Spider-Man-1963/Issue-549 already scraped.
# The-Amazing-Spider-Man-1963/Issue-548 already scraped.
# The-Amazing-Spider-Man-1963/Issue-547 already scraped.
# The-Amazing-Spider-Man-1963/Issue-546 already scraped.
# The-Amazing-Spider-Man-1963/Issue-545 already scraped.
# The-Amazing-Spider-Man-1963/Issue-544 already scraped.
# The-Amazing-Spider-Man-1963/Issue-543 already scraped.
# The-Amazing-Spider-Man-1963/Issue-542 already scraped.
# The-Amazing-Spider-Man-1963/Issue-541 already scraped.
# The-Amazing-Spider-Man-1963/Issue-540 already scraped.
# The-Amazing-Spider-Man-1963/Issue-539 already scraped.
# The-Amazing-Spider-Man-1963/Issue-538 already scraped.
# The-Amazing-Spider-Man-1963/Issue-537 already scraped.
# The-Amazing-Spider-Man-1963/Issue-536 already scraped.
# The-Amazing-Spider-Man-1963/Issue-535 already scraped.
# The-Amazing-Spider-Man-1963/Issue-534 already scraped.
# The-Amazing-Spider-Man-1963/Issue-533 already scraped.
# The-Amazing-Spider-Man-1963/Issue-532 already scraped.
# The-Amazing-Spider-Man-1963/Issue-531 already scraped.
# The-Amazing-Spider-Man-1963/Issue-530 already scraped.
# The-Amazing-Spider-Man-1963/Issue-529 already scraped.
# The-Amazing-Spider-Man-1963/Issue-528 already scraped.
# The-Amazing-Spider-Man-1963/Issue-527 already scraped.
# The-Amazing-Spider-Man-1963/Issue-526 already scraped.
# The-Amazing-Spider-Man-1963/Issue-525 already scraped.
# The-Amazing-Spider-Man-1963/Issue-524 already scraped.
# The-Amazing-Spider-Man-1963/Issue-523 already scraped.
# The-Amazing-Spider-Man-1963/Issue-522 already scraped.
# The-Amazing-Spider-Man-1963/Issue-521 already scraped.
# The-Amazing-Spider-Man-1963/Issue-520 already scraped.
# The-Amazing-Spider-Man-1963/Issue-519 already scraped.
# The-Amazing-Spider-Man-1963/Issue-518 already scraped.
# The-Amazing-Spider-Man-1963/Issue-517 already scraped.
# The-Amazing-Spider-Man-1963/Issue-516 already scraped.
# The-Amazing-Spider-Man-1963/Issue-515 already scraped.
# The-Amazing-Spider-Man-1963/Issue-514 already scraped.
# The-Amazing-Spider-Man-1963/Issue-513 already scraped.
# The-Amazing-Spider-Man-1963/Issue-512 already scraped.
# The-Amazing-Spider-Man-1963/Issue-511 already scraped.
# The-Amazing-Spider-Man-1963/Issue-510 already scraped.
# The-Amazing-Spider-Man-1963/Issue-509 already scraped.
# The-Amazing-Spider-Man-1963/Issue-508 already scraped.
# The-Amazing-Spider-Man-1963/Issue-507 already scraped.
# The-Amazing-Spider-Man-1963/Issue-506 already scraped.
# The-Amazing-Spider-Man-1963/Issue-505 already scraped.
# The-Amazing-Spider-Man-1963/Issue-504 already scraped.
# The-Amazing-Spider-Man-1963/Issue-503 already scraped.
# The-Amazing-Spider-Man-1963/Issue-502 already scraped.
# The-Amazing-Spider-Man-1963/Issue-501 already scraped.
# The-Amazing-Spider-Man-1963/Issue-500 already scraped.
# The-Amazing-Spider-Man-1963/Issue-441 already scraped.
# The-Amazing-Spider-Man-1963/Issue-440 already scraped.
# The-Amazing-Spider-Man-1963/Issue-439 already scraped.
# The-Amazing-Spider-Man-1963/Issue-438 already scraped.
# The-Amazing-Spider-Man-1963/Issue-437 already scraped.
# The-Amazing-Spider-Man-1963/Issue-436 already scraped.
# The-Amazing-Spider-Man-1963/Issue-435 already scraped.
# The-Amazing-Spider-Man-1963/Issue-434 already scraped.
# The-Amazing-Spider-Man-1963/Issue-433 already scraped.
# Now scraping: https://readcomiconline.to/Comic/The-Amazing-Spider-Man-1963/Issue-432
# Total issues scraped: 2
# The-Amazing-Spider-Man-1963/Issue-431 already scraped.
# The-Amazing-Spider-Man-1963/Issue-430 already scraped.
# Now scraping: https://readcomiconline.to/Comic/The-Amazing-Spider-Man-1963/Issue-429
# Total issues scraped: 3
# The-Amazing-Spider-Man-1963/Issue-428 already scraped.
# The-Amazing-Spider-Man-1963/Issue-427 already scraped.
# The-Amazing-Spider-Man-1963/Issue-426 already scraped.
# The-Amazing-Spider-Man-1963/Issue-425 already scraped.
# The-Amazing-Spider-Man-1963/Issue-424 already scraped.
# Now scraping: https://readcomiconline.to/Comic/The-Amazing-Spider-Man-1963/Issue-423
# Total issues scraped: 4
# The-Amazing-Spider-Man-1963/Issue-422 already scraped.
# The-Amazing-Spider-Man-1963/Issue-421 already scraped.
# The-Amazing-Spider-Man-1963/Issue-420 already scraped.
# The-Amazing-Spider-Man-1963/Issue-419 already scraped.
# The-Amazing-Spider-Man-1963/Issue-418 already scraped.
# The-Amazing-Spider-Man-1963/Issue-417 already scraped.
# The-Amazing-Spider-Man-1963/Issue-416 already scraped.
# The-Amazing-Spider-Man-1963/Issue-415 already scraped.
# The-Amazing-Spider-Man-1963/Issue-414 already scraped.
# The-Amazing-Spider-Man-1963/Issue-413 already scraped.
# The-Amazing-Spider-Man-1963/Issue-412 already scraped.
# The-Amazing-Spider-Man-1963/Issue-411 already scraped.
# The-Amazing-Spider-Man-1963/Issue-410 already scraped.
# The-Amazing-Spider-Man-1963/Issue-409 already scraped.
# The-Amazing-Spider-Man-1963/Issue-408 already scraped.
# The-Amazing-Spider-Man-1963/Issue-407 already scraped.
# The-Amazing-Spider-Man-1963/Issue-406 already scraped.
# Now scraping: https://readcomiconline.to/Comic/The-Amazing-Spider-Man-1963/Issue-405

# %%
df_temp = pd.read_csv('comic_comments/comic_comments.csv')

# %%
len(df_temp)
# Out:
# 8823

# %%
# TEST

# NO POSTS
nocomments = "https://disqus.com/embed/comments/?base=default&amp;f=readcomiconline&amp;t_i=e4670&amp;t_u=https%3A%2F%2Freadcomiconline.to%2FComic%2FThe-Amazing-Spider-Man-1963%2FIssue-432%3Fid%3D4670&amp;t_d=The%20Amazing%20Spider-Man%20(1963)%20Issue%20%23432%20-%20Read%20The%20Amazing%20Spider-Man%20(1963)%20Issue%20%23432%20comic%20online%20in%20high%20quality&amp;t_t=The%20Amazing%20Spider-Man%20(1963)%20Issue%20%23432%20-%20Read%20The%20Amazing%20Spider-Man%20(1963)%20Issue%20%23432%20comic%20online%20in%20high%20quality&amp;s_o=default#version=a710ee4b8f7d52e76441919a322769f5"
# POSTS
comments = "https://disqus.com/embed/comments/?base=default&amp;f=readcomiconline&amp;t_i=e135847&amp;t_u=https%3A%2F%2Freadcomiconline.to%2FComic%2FThe-Amazing-Spider-Man-1963%2FIssue-801%3Fid%3D135847&amp;t_d=The%20Amazing%20Spider-Man%20(1963)%20Issue%20%23801%20-%20Read%20The%20Amazing%20Spider-Man%20(1963)%20Issue%20%23801%20comic%20online%20in%20high%20quality&amp;t_t=The%20Amazing%20Spider-Man%20(1963)%20Issue%20%23801%20-%20Read%20The%20Amazing%20Spider-Man%20(1963)%20Issue%20%23801%20comic%20online%20in%20high%20quality&amp;s_o=default#version=a710ee4b8f7d52e76441919a322769f5"

# %%
source_code = requests.get(comments)
plain_text = source_code.text
soup = bs.BeautifulSoup(plain_text, 'html.parser')
print(len(soup_to_json(soup)))
# Out:
# 50

# %%
source_code = requests.get(nocomments)
plain_text = source_code.text
soup = bs.BeautifulSoup(plain_text, 'html.parser')
print(len(soup_to_json(soup)))
# Out:
# 0

# %%
df_comments = sentiment_analysis()

# %% [markdown]
# # 2. Comic Reviews EDA

# %% [markdown]
# ## 2.1 Most common review words

# %% [markdown]
# USE PREVIOUS NLP SpaCy notebook TO DETERMINE MOST COMMON WORDS
#
# GENERATE A TF-IDF OR WORD COUNT DF
#
# VISUALIZE BY USING WORDCLOUD
#
# https://www.youtube.com/watch?v=VraAbgAoYSk

# %%
temp = pd.read_csv('comic_comments/batman_2016_comments.csv')

# %%
# PLOT SENTIMENTS
